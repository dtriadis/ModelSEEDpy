# %% [markdown]
# # Define the models

# %%
# import kbase
import os
local_cobrakbase_path = os.path.join('C:', 'Users', 'Andrew Freiburger','Documents','Argonne','cobrakbase')
os.environ["HOME"] = local_cobrakbase_path
import cobrakbase
with open("D:/Users/Andrew Freiburger/Documents/Argonne/kbase_token.txt") as token_file:
    kbase_api = cobrakbase.KBaseAPI(token_file.readline())
model1 = kbase_api.get_from_ws("iML1515",76994)
# model2 = kbase_api.get_from_ws("iSB1139.kb.gf",30650)
# Out:
# cobrakbase 0.3.1

# %%
# sorted([rxn.id for rxn in model1.exchanges])

# %% [markdown]
# # Execute the simulation

# %%
cpd00020_e0 = 10
eval("12*cpd00020_e0/(1+cpd00020_e0)")
# Out:
# 10.909090909090908

# %%
# %run ../../../modelseedpy/community/mskineticsfba.py

# define in the initial conditions
initial_M = {
    "cpd00020_e0":1
}
kinetics = {
    "EX_cpd00020_e0": {
        "Martin et al., 2010": {
            # "metadata"
            "mets": ["cpd00020_e0"],
            "substituted_rate_law": "3*t*cpd00020_e0/(1.2+cpd00020_e0)"
        }
    }
}
total_time = 5
timestep = 1

# execute the package
kinFBA = MSKineticsFBA(model1)
conc, fluxes = kinFBA.baseKinFBA(kinetics_data=kinetics, initial_M=initial_M, export = False)
# Out:
#                  0 min  20 min
# metabolite (mM)
# cpd00020_e0       1000     0.0
#                             0 min  20 min
# reaction (Δmmol/hr*g_(dw)))
# 34dhpactex_e0                 NaN       0
# GUAtex_e0                     NaN       0
# rxn01256_c0                   NaN       0
# rxn00411_c0                   NaN       0
# rxn08277_c0                   NaN       0
# ...                           ...     ...
# EX_cpd00248_e0                NaN       0
# EX_cpd00151_e0                NaN       0
# SK_cpd02701_c0                NaN       0
# SK_cpd03091_c0                NaN       0
# SK_cpd01042_c0                NaN       0
#
# [2725 rows x 2 columns]
# 3*t*cpd00020_e0/(1.2+cpd00020_e0) 0.45454545454545453
#                  0 min        20 min  40 min
# metabolite (mM)
# cpd00020_e0       1000 -21818.181818     0.0
#                             0 min     20 min  40 min
# reaction (Δmmol/hr*g_(dw)))
# 34dhpactex_e0                 NaN   0.000000       0
# ...

# %%
from numpy import mean

print(type(mean([1,2,3])))

# %%
rxn = model1.exchanges[0]
rxn.lb = -20
print(rxn.bounds)
dic = {rxn.id: rxn}
dic[rxn.id].lb = -20
print(dic[rxn.id].bounds)
print(rxn.bounds)
print(model1.exchanges[0].bounds)
