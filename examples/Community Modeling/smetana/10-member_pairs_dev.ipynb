# %% [markdown]
# # Load KBase

# %%
# define the environment path 
import os
local_cobrakbase_path = os.path.join('C:', 'Users', 'Andrew Freiburger','Documents','Argonne','cobrakbase')
os.environ["HOME"] = local_cobrakbase_path

# import the KBase
import cobrakbase
# with open("/Users/afreiburger/Documents/kbase_token.txt") as token_file:
with open("D:/Users/Andrew Freiburger/Documents/Argonne/kbase_token.txt") as token_file:
    kbase_api = cobrakbase.KBaseAPI(token_file.readline())

# prevent excessive warnings
from time import process_time
import warnings
warnings.filterwarnings(action='once')
# %run ../../../modelseedpy/community/mssmetana.py
# Out:
# cobrakbase 0.3.1

# %%
locals().keys()
# Out:
# dict_keys(['__name__', '__doc__', '__package__', '__loader__', '__spec__', '__builtin__', '__builtins__', '_ih', '_oh', '_dh', 'In', 'Out', 'get_ipython', 'exit', 'quit', 'open', '_', '__', '___', '_i', '_ii', '_iii', '_i1', 'os', 'local_cobrakbase_path', 'cobrakbase', 'token_file', 'kbase_api', 'process_time', 'warnings', '__nonzero__', 'MSCompatibility', 'MSMinimalMedia', 'build_from_species_models', 'MSCommunity', 'combinations', 'permutations', 'chain', 'Variable', 'Constraint', 'Objective', 'ObjectiveError', 'ParameterError', 'array', 'unique', 'ndarray', 'where', 'sort', 'array_split', 'MSModelUtil', 'minimal_medium', 'Counter', 'DeepDiff', 'Iterable', 'Union', 'pprint', 'shuffle', 'current_process', 'ic', 'mean', 're', '_compatibilize', '_load_models', '_get_media', 'MSSmetana', '_i2', 'GCF_001421425', 'GCF_001421355', 'r2a_media', 'MSPackageManager', 'MSSteadyCom', 'ObjectAlreadyDefinedError', 'FeasibilityError', 'MSGapfill', 'FBAHelper', 'MSATPCorrection', 'Reaction', 'DictL
# ...

# %%
from modelseedpy.core.exceptions import ModelError
def test_pair(member1, member2, community):
    try:
        start_time = process_time()
        comm = MSSmetana([member1, member2], community)
        comm.all_scores()
        end_time = process_time()

        print(f"The {member1.id}_{member2.id} pair has been examined after {(end_time-start_time)/60} minutes.")
    except (ObjectiveError, ModelError, NameError) as e:
        print(f"\n\nERROR:{e}")

# %%
sample_pair = kbase_api.get_from_ws("136864/21/1")
print(sample_pair.optimize())
# Out:
# <Solution 52.733 at 0x2a0ca687c10>

# %%
mem_model = kbase_api.get_from_ws("136864/26/1")
for ex in mem_model.exchanges:
    print(ex.bounds)
# Out:
# (-1000, 1000)
# (-1000, 1000)
# (-1000, 1000)
# (-1000, 1000)
# (-1000, 1000)
# (-1000, 1000)
# (-1000, 1000)
# (-1000, 1000)
# (-1000, 1000)
# (-1000, 1000)
# (-1000, 1000)
# (-1000, 1000)
# (-1000, 1000)
# (-1000, 1000)
# (-1000, 1000)
# (-1000, 1000)
# (-1000, 1000)
# (-1000, 1000)
# (-1000, 1000)
# (-1000, 1000)
# (-1000, 1000)
# (-1000, 1000)
# (-1000, 1000)
# (-1000, 1000)
# (-1000, 1000)
# (-1000, 1000)
# (-1000, 1000)
# (-1000, 1000)
# (-1000, 1000)
# (-1000, 1000)
# (-1000, 1000)
# (-1000, 1000)
# (-1000, 1000)
# (-1000, 1000)
# (-1000, 1000)
# (-1000, 1000)
# (-1000, 1000)
# (-1000, 1000)
# (-1000, 1000)
# (-1000, 1000)
# (-1000, 1000)
# (-1000, 1000)
# (-1000, 1000)
# (-1000, 1000)
# (-1000, 1000)
# (-1000, 1000)
# (-1000, 1000)
# (-1000, 1000)
# (-1000, 1000)
# (-1000, 1000)
# (-1000, 1000)
# (-1000, 1000)
# (-1000, 1000)
# (-1000, 1000)
# (-1000, 1000)
# (-1000, 1000)
# (-1000, 1000)
# (-1000, 1000)
# (-1000, 1000)
# (-1000, 1000)
# (-1000, 1000)
# (-1000, 1000)
# ...

# %%
print(mem_model.slim_optimize())
for ex in mem_model.exchanges:
    ex.bounds = (-100,100)
print(mem_model.slim_optimize())
# Out:
# 74.84901254686409
# 7.99295963805741

# %%
AP49 = kbase_api.get_from_ws("Sphingobium_AP49_pacbio_v2.RAST.fbamodel", 114731)
# BC15 = kbase_api.get_from_ws("Bacillus_sp._bc15.RAST.fbamodel", 114731)
# AP49_BC15_model = kbase_api.get_from_ws("AP49-BC15",114731)
# community_media = _get_media(None, AP49_BC15_model, [AP49, BC15])

# %%
print(dir(AP49))
print(AP49.genome_ref)
# Out:
# ['OBJECT_TYPE', 'SBML_FIELD_ATTRIBUTES', 'SBML_FIELD_GAPFILLINGS', 'SBML_FIELD_GAPGENS', 'SBML_FIELD_GENOME_REFS', 'SBML_FIELD_MODEL_TYPE', 'SBML_FIELD_SOURCE', 'SBML_FIELD_SOURCE_ID', 'SBML_FIELD_TEMPLATE_REFS', '__VERSION__', '__class__', '__delattr__', '__dict__', '__dir__', '__doc__', '__enter__', '__eq__', '__exit__', '__format__', '__ge__', '__getattribute__', '__getstate__', '__gt__', '__hash__', '__init__', '__init_subclass__', '__le__', '__lt__', '__module__', '__ne__', '__new__', '__reduce__', '__reduce_ex__', '__repr__', '__setattr__', '__setstate__', '__sizeof__', '__str__', '__subclasshook__', '__weakref__', '_annotation', '_compartments', '_contexts', '_from_json', '_get_computed_attributes', '_get_gapfillings', '_get_gapgens', '_get_genome_ref', '_get_source', '_get_source_id', '_get_template_ref', '_get_type', '_id', '_model_compartments', '_populate_solver', '_repr_html_', '_set_computed_attributes', '_set_gapfillings', '_set_gapgens', '_set_genome_ref', '_set_id_wit
# ...

# %%
kbase_api.get_from_ws(AP49.genome_ref)
# Out:
#         <table>
#             <tr>
#                 <td><strong>ID</strong></td>
#                 <td>Sphingobium_AP49_pacbio_v2.RAST</td>
#             </tr><tr>
#                 <td><strong>Scientific Name</strong></td>
#                 <td>Genus species Unclassified. (Unknown)</td>
#             </tr><tr>
#                 <td><strong>Taxonomy</strong></td>
#                 <td>Unconfirmed Organism</td>
#             </tr><tr>
#                 <td><strong>Sequence Data</strong></td>
#                 <td>Size: 4506188, Contigs: 1, GC: 0.641</td>
#             </tr><tr>
#                 <td><strong>CDS</strong></td>
#                 <td>4162</td>
#             </tr><tr>
#                 <td><strong>Features</strong></td>
#                 <td>4162</td>
#             </tr><tr>
#                 <td><strong>MD5</strong></td>
#                 <td>8ce6d488116d9c9d1f9e1c8674295938</td>
#             </tr>
#           </table>

# %%
from itertools import combinations

list(combinations([1,2,3], 2))
# Out:
# [(1, 2), (1, 3), (2, 3)]

# %%
test_pair(AP49, BC15, None)
# Out:
# The exchange  metabolite ID's of the model Sphingobium_AP49_pacbio_v2.RAST.fbamodel,Bacillus_sp._bc15.RAST.fbamodel are completely standardized to ModelSEED.
#
#
#
# Align exchange reactions in Sphingobium_AP49_pacbio_v2.RAST.fbamodel
# ...
#
#
#
# Align exchange reactions in Bacillus_sp._bc15.RAST.fbamodel
# ...
#
#
# 0 exchange reactions were substituted and 0 exchange metabolite IDs were redefined by align_exchanges().
# [<ModelCompound cpd11416_c1 at 0x1b304f199d0>, <ModelCompound cpd11416_c2 at 0x1b3081603a0>, <Metabolite cpd11416_c0 at 0x1b30b1a8910>]
# The minimal flux media consists of 42 compounds and a 1.997562023899096 total influx, with a growth value of 0.0999999999995738
# The minimal flux media consists of 36 compounds and a 1.4912990953788197 total influx, with a growth value of 0.09999999999989304
#
# ...

# %%
# from optlang.interface import Configuration
# Configuration(AP49_BC15_model.problem, timeout=10)
# obj = Objective(AP49_BC15_model.reactions.bio1.flux_expression) #, time_out=10)
# print(dir(Objective))
# print(dir(AP49_BC15_model))

# %%
# from modelseedpy.core import MSMinimalMedia
# %run ../../../modelseedpy/core/msminimalmedia.py
print(MSMinimalMedia.determine_min_media(AP49_BC15_model))
# Out:
# C:\Users\Andrew Freiburger\Documents\Argonne\ModelSEED\ModelSEEDpy\modelseedpy\core\msminimalmedia.py:231: DeprecationWarning: invalid escape sequence \[
#   changed_reactions = [re.search("(?<=\[\')(.+)(?=\'\])", change).group() for change in changes]
# EX_cpd00156_e0       0.146647
# EX_cpd00355_e0    1000.000000
# EX_cpd00007_e0    1000.000000
# EX_cpd00028_e0       0.000561
# EX_cpd10515_e0       0.001684
# EX_cpd00793_e0       0.000561
# EX_cpd00048_e0     137.587012
# EX_cpd00220_e0       0.001684
# EX_cpd00215_e0       0.000561
# EX_cpd00393_e0       0.001684
# EX_cpd00099_e0       0.000561
# EX_cpd00030_e0       0.000561
# EX_cpd00149_e0       0.000561
# EX_cpd00063_e0       0.000561
# EX_cpd00205_e0       0.000561
# EX_cpd00254_e0       0.000561
# EX_cpd00034_e0       0.000561
# EX_cpd00058_e0       0.000561
# EX_cpd00322_e0       0.048360
# EX_cpd00104_e0       0.000561
# dtype: float64
# ...

# %%
print(len({'EX_cpd00028_e0': 0.0005612318319663245, 'EX_cpd00047_e0': 3.197442310920451e-13, 'EX_cpd00104_e0': 0.0005612318319663245, 'EX_cpd00226_e0': 8.428327480380915e-13, 'EX_cpd00063_e0': 0.0005612318319663245, 'EX_cpd00024_e0': 9.598286376623291e-14, 'EX_cpd00254_e0': 0.0005612318319663245, 'EX_cpd00322_e0': 0.04835970206750062, 'EX_cpd00793_e0': 0.0005612318318526377, 'EX_cpd00099_e0': 0.0005612318319663245, 'EX_cpd00731_e0': 1.824638530545375e-13, 'EX_cpd00355_e0': 375.85961192867086, 'EX_cpd00971_e0': 1.1368683772161603e-13, 'EX_cpd00179_e0': 8.569950304959659e-13, 'EX_cpd00117_e0': 4.3662989890336235e-15, 'EX_cpd00034_e0': 0.0005612318319663245, 'EX_cpd00220_e0': 0.0016836954956716, 'EX_cpd00182_e0': 1.1097234242640752e-12, 'EX_cpd00007_e0': 467.4134812927798, 'EX_cpd00058_e0': 0.0005612318319663245, 'EX_cpd00149_e0': 0.0005612318319663245, 'EX_cpd00393_e0': 0.0016836954956716, 'EX_cpd10515_e0': 0.0016836954957852868, 'EX_cpd00205_e0': 0.0005612318319663245, 'EX_cpd00084_e0': 8.811406465580873e-13, 'EX_cpd00161_e0': 5.93275428784068e-16, 'EX_cpd00215_e0': 0.0005612318319663245, 'EX_cpd00156_e0': 0.14664687099036655, 'EX_cpd00048_e0': 0.043595742118782255, 'EX_cpd00030_e0': 0.0005612318319663245, 'EX_cpd00412_e0': 6.94548585311594e-14, 'EX_cpd00305_e0': 6.915386793914337e-16, 'EX_cpd00013_e0': 2.842170943040401e-14}))
# Out:
# 33

# %%
print(len({'EX_cpd00793_e0': 0.0005612318318526377, 'EX_cpd00063_e0': 0.0005612318319663245, 'EX_cpd00028_e0': 0.0005612318319663245, 'EX_cpd00058_e0': 0.0005612318319663245, 'EX_cpd00205_e0': 0.0005612318319663245, 'EX_cpd00048_e0': 347.6805135456988, 'EX_cpd00007_e0': 0.0022449273280293596, 'EX_cpd00254_e0': 0.0005612318319663245, 'EX_cpd00149_e0': 0.0005612318319663245, 'EX_cpd00104_e0': 0.0005612318319663245, 'EX_cpd00099_e0': 0.0005612318319663245, 'EX_cpd00156_e0': 999.5521052674475, 'EX_cpd00322_e0': 0.04835970206750062, 'EX_cpd00215_e0': 0.0005612318319663245, 'EX_cpd00393_e0': 0.0016836954957852868, 'EX_cpd00030_e0': 0.0005612318319663245, 'EX_cpd00034_e0': 0.0005612318319663245, 'EX_cpd00355_e0': 1000.0, 'EX_cpd10515_e0': 0.0016836954957852868, 'EX_cpd00220_e0': 0.0016836954956716}))
# Out:
# 20

# %%
# %run ../../../modelseedpy/community/mssmetana.py
comm = MSSmetana([AP49, BC15], AP49_BC15_model)
print(len(comm.media), comm.media)
# Out:
# The exchange  metabolite ID's of the model Sphingobium_AP49_pacbio_v2.RAST.fbamodel,Bacillus_sp._bc15.RAST.fbamodel are completely standardized to ModelSEED.
# com_mdeia_est
# <Solution 59.661 at 0x21a4c93a910>
# C:\Users\Andrew Freiburger\AppData\Local\Programs\Python\Python39\lib\site-packages\cobra\medium\minimal_medium.py:112: FutureWarning: The default dtype for empty Series will be 'object' instead of 'float64' in a future version. Specify a dtype explicitly to silence this warning.
#   medium = pd.Series()
# <Solution 169.734 at 0x21a4d895c10>
# C:\Users\Andrew Freiburger\AppData\Local\Programs\Python\Python39\lib\site-packages\cobra\medium\minimal_medium.py:112: FutureWarning: The default dtype for empty Series will be 'object' instead of 'float64' in a future version. Specify a dtype explicitly to silence this warning.
#   medium = pd.Series()
# 2 {'community_media': EX_cpd00156_e0       0.146647
# EX_cpd00355_e0    1000.000000
# EX_cpd00007_e0    1000.000000
# ...

# %%
from pprint import pprint

print(len(comm.media["community_media"]), comm.media["community_media"])
pprint([(len(comm.media["members"][member]["media"]), comm.media["members"][member]["media"]) for member in comm.media["members"]])
# Out:
# 20 EX_cpd00156_e0       0.146647
# EX_cpd00355_e0    1000.000000
# EX_cpd00007_e0    1000.000000
# EX_cpd00028_e0       0.000561
# EX_cpd10515_e0       0.001684
# EX_cpd00793_e0       0.000561
# EX_cpd00048_e0     137.587012
# EX_cpd00220_e0       0.001684
# EX_cpd00215_e0       0.000561
# EX_cpd00393_e0       0.001684
# EX_cpd00099_e0       0.000561
# EX_cpd00030_e0       0.000561
# EX_cpd00149_e0       0.000561
# EX_cpd00063_e0       0.000561
# EX_cpd00205_e0       0.000561
# EX_cpd00254_e0       0.000561
# EX_cpd00034_e0       0.000561
# EX_cpd00058_e0       0.000561
# EX_cpd00322_e0       0.048360
# EX_cpd00104_e0       0.000561
# dtype: float64
# [(21,
#   EX_cpd00009_e0      0.080975
# EX_cpd00156_e0      0.072762
# EX_cpd00007_e0    963.085589
# EX_cpd00644_e0      0.000561
# EX_cpd00028_e0      0.000281
# EX_cpd00122_e0    845.641610
# EX_cpd00793_e0      0.000281
# EX_cpd00048_e0     23.956554
# EX_cpd00220_e0      0.000842
# EX_cpd00215_e0      0.000281
# ...

# %%
comm.mip_score()
# Out:
# ic| mssmetana.py:30 in _load_models()
#     member_models: [<FBAModel Sphingobium_AP49_pacbio_v2.RAST.fbamodel at 0x21a4495f2e0>,
#                     <FBAModel Bacillus_sp._bc15.RAST.fbamodel at 0x21a49e133a0>]
#     com_model: <FBAModel AP49-BC15 at 0x21a44f59400>
#     compatibilize: False
# {}
#
# MIP score: 0			0 required compound(s) can be sourced via syntrophy:
# C:\Users\Andrew Freiburger\AppData\Local\Programs\Python\Python39\lib\site-packages\cobra\medium\minimal_medium.py:112: FutureWarning: The default dtype for empty Series will be 'object' instead of 'float64' in a future version. Specify a dtype explicitly to silence this warning.
#   medium = pd.Series()
# 0

# %%
comm.mp_score()
# Out:
# executing MP
# The exchange  metabolite ID's of the model AP49-BC15 are completely standardized to ModelSEED.
# The minimal flux media consists of 39 compounds and a 2387.7714268772957 total influx, with a growth value of 59.66143917485788
#
#
#
# Standardize exchange reactions in Sphingobium_AP49_pacbio_v2.RAST.fbamodel
# ...
# The exchange  metabolite ID's of the model Sphingobium_AP49_pacbio_v2.RAST.fbamodel are completely standardized to ModelSEED.
# C:\Users\Andrew Freiburger\AppData\Local\Programs\Python\Python39\lib\site-packages\cobra\core\reaction.py:761: DeprecationWarning: Please use reaction.flux instead.
#   warn("Please use reaction.flux instead.", DeprecationWarning)
# C:\Users\Andrew Freiburger\AppData\Local\Programs\Python\Python39\lib\site-packages\cobra\core\reaction.py:779: DeprecationWarning: Please use reaction.reduced_cost instead.
#   warn("Please use reaction.reduced_cost instead.", DeprecationWarning)
# ...

# %%
# %run ../../../modelseedpy/community/mssmetana.py
comm = MSSmetana([AP49, BC15], AP49_BC15_model)
comm.mu_score()
# Out:
# The exchange  metabolite ID's of the model Sphingobium_AP49_pacbio_v2.RAST.fbamodel,Bacillus_sp._bc15.RAST.fbamodel are completely standardized to ModelSEED.
# com_mdeia_est
# <Solution 59.661 at 0x17b3f7c0ca0>
# C:\Users\Andrew Freiburger\AppData\Local\Programs\Python\Python39\lib\site-packages\cobra\medium\minimal_medium.py:112: FutureWarning: The default dtype for empty Series will be 'object' instead of 'float64' in a future version. Specify a dtype explicitly to silence this warning.
#   medium = pd.Series()
# <Solution 169.734 at 0x17b40795e20>
# C:\Users\Andrew Freiburger\AppData\Local\Programs\Python\Python39\lib\site-packages\cobra\medium\minimal_medium.py:112: FutureWarning: The default dtype for empty Series will be 'object' instead of 'float64' in a future version. Specify a dtype explicitly to silence this warning.
#   medium = pd.Series()
# ...

# %%
# %run ../../../modelseedpy/community/mssmetana.py
comm.mp = {'Sphingobium_AP49_pacbio_v2.RAST.fbamodel': {'cpd00797_e0', 'cpd00036_e0', 'cpd00116_e0', 'cpd03279_e0', 'cpd00053_e0', 'cpd00013_e0', 'cpd00412_e0', 'cpd00023_e0', 'cpd00276_e0', 'cpd00182_e0', 'cpd00438_e0', 'cpd00122_e0', 'cpd00184_e0', 
                                                        'cpd00246_e0', 'cpd00084_e0', 'cpd00249_e0', 'cpd00033_e0', 'cpd00060_e0', 'cpd00075_e0', 'cpd00039_e0', 'cpd00067_e0', 'cpd00011_e0', 'cpd00137_e0', 'cpd00588_e0', 'cpd00054_e0', 'cpd00001_e0', 
                                                        'cpd00041_e0', 'cpd00129_e0', 'cpd00161_e0', 'cpd00138_e0', 'cpd00132_e0'}, 
           'Bacillus_sp._bc15.RAST.fbamodel': {'cpd00064_e0', 'cpd00797_e0', 'cpd03279_e0', 'cpd00130_e0', 'cpd00116_e0', 'cpd00053_e0', 'cpd00013_e0', 'cpd00012_e0', 'cpd00412_e0', 'cpd00023_e0', 'cpd00276_e0', 'cpd00142_e0', 'cpd00309_e0', 'cpd00182_e0', 
                                               'cpd00438_e0', 'cpd00092_e0', 'cpd00122_e0', 'cpd00184_e0', 'cpd00246_e0', 'cpd00159_e0', 'cpd00084_e0', 'cpd00082_e0', 'cpd00249_e0', 'cpd00033_e0', 'cpd00060_e0', 'cpd00075_e0', 'cpd00039_e0', 'cpd00226_e0', 
                                               'cpd00047_e0', 'cpd00067_e0', 'cpd00080_e0', 'cpd00011_e0', 'cpd00137_e0', 'cpd00100_e0', 'cpd00073_e0', 'cpd00180_e0', 'cpd00117_e0', 'cpd00054_e0', 'cpd00001_e0', 'cpd00009_e0', 'cpd00041_e0', 'cpd00129_e0', 
                                               'cpd00161_e0', 'cpd00138_e0', 'cpd00218_e0', 'cpd00132_e0'}}
comm.mu_score()

# %%
# %time comm.mro_score()

# %%
# %run ../../../modelseedpy/community/mssmetana.py
comm = MSSmetana([AP49, BC15], AP49_BC15_model)
# %time comm.mip_score()

# %%
# %run ../../../modelseedpy/community/mssmetana.py
# comm = MSSmetana([AP49, BC15], AP49_BC15_model)
# %time comm.sc_score()

# %% [markdown]
# # test community pairs

# %% [markdown]
# # "+" interactions

# %% [markdown]
# ## YR343 on CF142

# %%
# from cobra.medium import minimal_medium
# media = minimal_medium(YR343, minimize_components=True).to_dict()

# %%
# print(media)
# for cpd in media:
#     print(cpd)

# %%
# %%time

# load the pair
YR343 = kbase_api.get_from_ws("Pantoea_YR343_pacbio_v2.RAST.fbamodel", 114731)
print(YR343.optimize())
CF142 = kbase_api.get_from_ws("Rhizobium_CF142_pacbio_v2.RAST.fbamodel", 114731)
YR343_CF142_model = kbase_api.get_from_ws("YR343-CF142", 114731)
test_pair(YR343, CF142, YR343_CF142_model)
# Out:
# <Solution 181.758 at 0x23e640ebd30>
# modelseedpy.community.mscompatibility - WARNING - IDWarning: The original ID cpd00609_e0 is a ModelSEED ID, and may not be desirably changed to cpd00609_e0.
# 0 reactions were substituted and 1 metabolite IDs were redefined in Pantoea_YR343_pacbio_v2.RAST.fbamodel,Rhizobium_CF142_pacbio_v2.RAST.fbamodel by standardize().
#
#
# ERROR:The model Rhizobium_CF142_pacbio_v2.RAST.fbamodel possesses an objective value of 0 in complete media, which is incompatible with minimal media computations and hence SMETANA.
# CPU times: total: 6.5 s
# Wall time: 7.71 s

# %% [markdown]
# ## YR343 on CF313

# %%
# load the pair
CF313 = kbase_api.get_from_ws("Variovorax_CF313_pacbio_v2.RAST.fbamodel",114731)
YR343_CF313_model = kbase_api.get_from_ws("YR343-CF313",114731)

# %%
# %%time

# %run ../../../modelseedpy/core/msminimalmedia.py
# %time media = MSMinimalMedia.minimize_components(CF313)
# print(len(media), media)
test_pair(YR343, CF313, YR343_CF313_model)
# Out:
# modelseedpy.community.mscompatibility - WARNING - IDWarning: The original ID cpd00609_e0 is a ModelSEED ID, and may not be desirably changed to cpd00609_e0.
# 0 reactions were substituted and 1 metabolite IDs were redefined in Pantoea_YR343_pacbio_v2.RAST.fbamodel,Variovorax_CF313_pacbio_v2.RAST.fbamodel by standardize().
# com_mdeia_est
# <Solution 181.758 at 0x23e70ee55e0>
# C:\Users\Andrew Freiburger\AppData\Local\Programs\Python\Python39\lib\site-packages\cobra\medium\minimal_medium.py:112: FutureWarning: The default dtype for empty Series will be 'object' instead of 'float64' in a future version. Specify a dtype explicitly to silence this warning.
#   medium = pd.Series()
# <Solution 133.789 at 0x23e72e66e80>
# ...

# %% [markdown]
# ## AP49 on BC15

# %%
AP49 = kbase_api.get_from_ws("Sphingobium_AP49_pacbio_v2.RAST.fbamodel", 114731)
BC15 = kbase_api.get_from_ws("Bacillus_sp._bc15.RAST.fbamodel", 114731)
AP49_BC15_model = kbase_api.get_from_ws("AP49-BC15", 114731)
test_pair(AP49, BC15, AP49_BC15_model)
# Out:
# The exchange  metabolite ID's of the model Sphingobium_AP49_pacbio_v2.RAST.fbamodel,Bacillus_sp._bc15.RAST.fbamodel are completely standardized to ModelSEED.
# com_mdeia_est
# <Solution 59.661 at 0x2411e70f7f0>
# C:\Users\Andrew Freiburger\AppData\Local\Programs\Python\Python39\lib\site-packages\cobra\medium\minimal_medium.py:112: FutureWarning: The default dtype for empty Series will be 'object' instead of 'float64' in a future version. Specify a dtype explicitly to silence this warning.
#   medium = pd.Series()
# <Solution 169.734 at 0x2416b47ebb0>
# C:\Users\Andrew Freiburger\AppData\Local\Programs\Python\Python39\lib\site-packages\cobra\medium\minimal_medium.py:112: FutureWarning: The default dtype for empty Series will be 'object' instead of 'float64' in a future version. Specify a dtype explicitly to silence this warning.
#   medium = pd.Series()
# ...

# %% [markdown]
# ## CF142 on BC15

# %%
CF142_BC15_model = kbase_api.get_from_ws("CF142-BC15", 114731)
test_pair(CF142, BC15, CF142_BC15_model)
# Out:
# The exchange  metabolite ID's of the model Rhizobium_CF142_pacbio_v2.RAST.fbamodel,Bacillus_sp._bc15.RAST.fbamodel are completely standardized to ModelSEED.
#
#
# ERROR:The model Rhizobium_CF142_pacbio_v2.RAST.fbamodel possesses an objective value of 0 in complete media, which is incompatible with minimal media computations and hence SMETANA.

# %% [markdown]
# ## CF402 on CF313

# %%
CF402 = kbase_api.get_from_ws("Duagnella_sp_CF402.RAST.fbamodel", 114731)
CF313 = kbase_api.get_from_ws("Variovorax_CF313_pacbio_v2.RAST.fbamodel",114731)
CF402_CF313_model = kbase_api.get_from_ws("CF402-CF313", 114731)
test_pair(CF402, CF313, CF402_CF313_model)

# %% [markdown]
# ## CF402 on BC15

# %%
CF402 = kbase_api.get_from_ws("Duagnella_sp_CF402.RAST.fbamodel", 114731)
BC15 = kbase_api.get_from_ws("Bacillus_sp._bc15.RAST.fbamodel", 114731)
CF402_BC15_model = kbase_api.get_from_ws("CF402-BC15", 114731)
test_pair(CF402, BC15, CF402_BC15_model)

# %%
from cobra.medium import minimal_medium
display(sorted(list(minimal_medium(CF402, minimize_components=True).keys())))
display(sorted(list(minimal_medium(BC15, minimize_components=True).keys())))
display(set(list(minimal_medium(BC15, minimize_components=True).keys())) & set(list(minimal_medium(CF402, minimize_components=True).keys())))

# %% [markdown]
# # "-" interactions

# %% [markdown]
# ## GM17 on CF142

# %%
GM17 = kbase_api.get_from_ws("Pseudomonas_GM17_pacbio_v2.RAST.fbamodel", 114731)
CF142 = kbase_api.get_from_ws("Rhizobium_CF142_pacbio_v2.RAST.fbamodel", 114731)
GM17_CF142_model = kbase_api.get_from_ws("GM17-CF142", 114731)
test_pair(GM17, CF142, GM17_CF142_model)

# %% [markdown]
# ## GM17 on BC15

# %%
GM17 = kbase_api.get_from_ws("Pseudomonas_GM17_pacbio_v2.RAST.fbamodel", 114731)
BC15 = kbase_api.get_from_ws("Bacillus_sp._bc15.RAST.fbamodel", 114731)
GM17_BC15_model = kbase_api.get_from_ws("GM17-BC15", 114731)
test_pair(GM17, BC15, GM17_BC15_model)

# %% [markdown]
# ## CF313 on CF142

# %%
CF313_CF142_model = kbase_api.get_from_ws("CF313-CF142", 114731)
test_pair(CF313, CF142, CF313_CF142_model)

# %% [markdown]
# ## AP07 on AP49

# %%
AP07 = kbase_api.get_from_ws("Caulobacter_AP07_pacbio_v2.RAST.fbamodel", 114731)
AP49 = kbase_api.get_from_ws("Sphingobium_AP49_pacbio_v2.RAST.fbamodel", 114731)
AP07_AP49_model = kbase_api.get_from_ws("AP07-AP49", 114731)
test_pair(AP07, AP49, AP07_AP49_model)

# %% [markdown]
# ## CF313 on BT03

# %%
BT03 = kbase_api.get_from_ws("Burkholderia_sp._BT03.RAST.fbamodel", 114731)
CF313 = kbase_api.get_from_ws("Variovorax_CF313_pacbio_v2.RAST.fbamodel",114731)
CF313_BT03_model = kbase_api.get_from_ws("CF313-BT03", 114731)
test_pair(CF313, BT03, CF313_BT03_model)

# %% [markdown]
# ## YR139 on CF142

# %%
YR139 = kbase_api.get_from_ws("Streptomyces_YR139_pacbio_v2.RAST.fbamodel", 114731)
YR139_CF142_model = kbase_api.get_from_ws("YR139-CF142", 114731)
test_pair(YR139, CF142, YR139_CF142_model)

# %% [markdown]
# ## GM17 on AP49

# %%
GM17_AP49_model = kbase_api.get_from_ws("GM17-AP49", 114731)
test_pair(GM17, AP49, GM17_AP49_model)

# %% [markdown]
# ## GM17 on CF313

# %%
GM17_CF313_model = kbase_api.get_from_ws("GM17-CF313", 114731)
test_pair(GM17, CF313, GM17_CF313_model)

# %% [markdown]
# ## GM17 on AP07

# %%
GM17_AP07_model = kbase_api.get_from_ws("GM17-AP07", 114731)
test_pair(GM17, AP07, GM17_AP07_model)

# %% [markdown]
# ## GM17 on CF402

# %%
GM17_CF402_model = kbase_api.get_from_ws("GM17-CF402", 114731)
test_pair(GM17, CF402, GM17_CF402_model)

# %% [markdown]
# ## GM17 on BT03

# %%
GM17_BT03_model = kbase_api.get_from_ws("GM17-BT03", 114731)
test_pair(GM17, BT03, GM17_BT03_model)

# %%
from cobra.medium import minimal_medium
len(minimal_medium(CF402, minimize_components=True))

# %% [markdown]
# # Functional complementarity score

# %%
# define the environment path 
import os
local_cobrakbase_path = os.path.join('C:', 'Users', 'Andrew Freiburger','Documents','Argonne','cobrakbase')
os.environ["HOME"] = local_cobrakbase_path

# import the KBase
import cobrakbase
# with open("/Users/afreiburger/Documents/kbase_token.txt") as token_file:
with open("D:/Users/Andrew Freiburger/Documents/Argonne/kbase_token.txt") as token_file:
    kbase_api = cobrakbase.KBaseAPI(token_file.readline())

# prevent excessive warnings
from time import process_time
import warnings
warnings.filterwarnings(action='once')
# %run ../../../modelseedpy/community/mssmetana.py
# Out:
# cobrakbase 0.3.1
# C:\Users\Andrew Freiburger\Documents\Argonne\ModelSEED\ModelSEEDpy\modelseedpy\community\mssmetana.py:417: DeprecationWarning: invalid escape sequence \[
#   cross_fed_exIDs = [re.sub("(root\['|'\])", "", x) for x in interact_diff["dictionary_item_removed"]]

# %%
AP49_info = ("Sphingobium_AP49_pacbio_v2.RAST.fbamodel", 114731) ; BC15_info = ("Bacillus_sp._bc15.RAST.fbamodel", 114731)
BT03_info = ("Burkholderia_sp._BT03.RAST.fbamodel", 114731) ; YR139_info = ("Streptomyces_YR139_pacbio_v2.RAST.fbamodel", 114731)
CF313_info = ("Variovorax_CF313_pacbio_v2.RAST.fbamodel",114731) ; AP07_info = ("Caulobacter_AP07_pacbio_v2.RAST.fbamodel", 114731)
CF402_info = ("Duagnella_sp_CF402.RAST.fbamodel", 114731) ; GM17_info = ("Pseudomonas_GM17_pacbio_v2.RAST.fbamodel", 114731)
YR343_info = ("Pantoea_YR343_pacbio_v2.RAST.fbamodel", 114731)

# %%
pmi_models = [AP49_info, BC15_info, BT03_info, YR139_info, CF313_info, AP07_info, CF402_info, GM17_info, YR343_info]
neutral_interactions = {
    YR343_info: [GM17_info, AP49_info, BC15_info, AP07_info, CF402_info, BT03_info],
    BT03_info: [GM17_info, YR139_info, BC15_info, AP07_info, CF402_info],
    CF313_info: [BC15_info, YR139_info],
    AP07_info: [CF313_info, BC15_info],
    AP49_info: [CF402_info, BT03_info],
    YR139_info: [BC15_info, CF402_info]
}

positive_interactions = {
    YR343_info: [CF313_info],
    AP49_info: [BC15_info],
    CF402_info: [CF313_info, BC15_info],
}

negative_interactions = {
    GM17_info: [BC15_info, AP49_info, CF313_info, AP07_info, CF402_info, BT03_info],
    CF313_info: [BT03_info],
    AP07_info: [AP49_info]
}

r2a_media = kbase_api.get_from_ws("136582/402/1")

# %%
AP49 = kbase_api.get_from_ws("Sphingobium_AP49_pacbio_v2.RAST.fbamodel", 114731) ; BC15 = kbase_api.get_from_ws("Bacillus_sp._bc15.RAST.fbamodel", 114731)
BT03 = kbase_api.get_from_ws("Burkholderia_sp._BT03.RAST.fbamodel", 114731) ; YR139 = kbase_api.get_from_ws("Streptomyces_YR139_pacbio_v2.RAST.fbamodel", 114731)
print("done 1/2", end="\r")
CF313 = kbase_api.get_from_ws("Variovorax_CF313_pacbio_v2.RAST.fbamodel",114731) ; AP07 = kbase_api.get_from_ws("Caulobacter_AP07_pacbio_v2.RAST.fbamodel", 114731)
CF402 = kbase_api.get_from_ws("Duagnella_sp_CF402.RAST.fbamodel", 114731) ; GM17 = kbase_api.get_from_ws("Pseudomonas_GM17_pacbio_v2.RAST.fbamodel", 114731)
YR343 = kbase_api.get_from_ws("Pantoea_YR343_pacbio_v2.RAST.fbamodel", 114731)

r2a_media = kbase_api.get_from_ws("136582/402/1")

print("done\t\t")



pmi_models = [AP49, BC15, BT03, YR139, CF313, AP07, CF402, GM17, YR343]
neutral_interactions = {
    YR343: [GM17, AP49, BC15, AP07, CF402, BT03],
    BT03: [GM17, YR139, BC15, AP07, CF402],
    CF313: [BC15, YR139],
    AP07: [CF313, BC15],
    AP49: [CF402, BT03],
    YR139: [BC15, CF402]
}

positive_interactions = {
    YR343: [CF313],
    AP49: [BC15],
    CF402: [CF313, BC15],
}

negative_interactions = {
    GM17: [BC15, AP49, CF313, AP07, CF402, BT03],
    CF313: [BT03],
    AP07: [AP49]
}

# %%
PMI_models_media = {
    'Bacillus_sp._bc15.RAST.fbamodel': {
        'media': {
            'EX_cpd00051_e0': 0.024950298185467054, 'EX_cpd00644_e0': 0.0005612318319214348, 'EX_cpd00654_e0': 0.0011184174481049735, 'EX_cpd00393_e0': 0.0008418477478827718, 'EX_cpd00149_e0': 0.00028061591596092344, 
            'EX_cpd00030_e0': 0.0002806159159609234, 'EX_cpd00182_e0': 0.012823174793819692, 'EX_cpd00367_e0': 0.019860385045891646, 'EX_cpd00063_e0': 0.0002806159159609234, 'EX_cpd00066_e0': 0.015451949003231678, 
            'EX_cpd00099_e0': 0.00028061591596092344, 'EX_cpd15603_e0': 0.040392130687977465, 'EX_cpd00254_e0': 0.00028061591596092344, 'EX_cpd00264_e0': 0.00028061591596092344, 'EX_cpd00209_e0': 0.29280989138763885, 
            'EX_cpd00007_e0': 0.0007015397899023084, 'EX_cpd00104_e0': 0.00028061591596092344, 'EX_cpd00158_e0': 0.8572001890264485, 'EX_cpd00065_e0': 0.004720191914454185, 'EX_cpd10515_e0': 0.0008418477478827702, 
            'EX_cpd00069_e0': 0.012067660460609869, 'EX_cpd00048_e0': 0.00028061591596092344, 'EX_cpd00793_e0': 0.0002806159159609235, 'EX_cpd00058_e0': 0.00028061591596092344, 'EX_cpd00107_e0': 0.037538884754252475, 
            'EX_cpd00119_e0': 0.00792636000742222, 'EX_cpd00156_e0': 0.035223318909387485, 'EX_cpd00034_e0': 0.00028061591596092344, 'EX_cpd00179_e0': 4.162129853322901e-13, 'EX_cpd00017_e0': 0.0019643114116915986, 
            'EX_cpd00205_e0': 0.00028061591596092344, 'EX_cpd00277_e0': 0.014659099568563774, 'EX_cpd00355_e0': 0.08097665993895736, 'EX_cpd00220_e0': 0.0008418477478827705, 'EX_cpd00322_e0': 0.024179851033877948, 
            'EX_cpd00028_e0': 0.00028061591596092344}
        }, 
    'Sphingobium_AP49_pacbio_v2.RAST.fbamodel': {
        'media': {
            'EX_cpd00039_e0': 0.028543802049017904, 'EX_cpd00118_e0': 0.000280615915959131, 'EX_cpd01017_e0': 0.008456496968388943, 'EX_cpd00051_e0': 0.024669682270134097, 'EX_cpd00136_e0': 0.00028061591595913087, 
            'EX_cpd00161_e0': 0.03565680232766155, 'EX_cpd00009_e0': 0.08097472586643507, 'EX_cpd00644_e0': 0.0005612318318649744, 'EX_cpd00654_e0': 0.0011501166238305303, 'EX_cpd00393_e0': 0.0008418477478774078, 
            'EX_cpd00149_e0': 0.000280615915959131, 'EX_cpd00030_e0': 0.000280615915959131, 'EX_cpd00132_e0': 0.0200830806928348, 'EX_cpd00060_e0': 0.011096446763321909, 'EX_cpd00063_e0': 0.000280615915959131, 
            'EX_cpd00066_e0': 0.015451949003134501, 'EX_cpd00099_e0': 0.00028061591595913103, 'EX_cpd00794_e0': 0.2508330788175711, 'EX_cpd03847_e0': 0.00250105977108944, 'EX_cpd00254_e0': 0.00028061591595913103, 
            'EX_cpd00264_e0': 0.000280615915959131, 'EX_cpd00007_e0': 1.181243853603619, 'EX_cpd00104_e0': 0.000280615915959131, 'EX_cpd00065_e0': 0.004720191914502181, 'EX_cpd10515_e0': 0.0008418477478773928, 
            'EX_cpd00069_e0': 0.0120676604606612, 'EX_cpd00053_e0': 0.20365017006808284, 'EX_cpd00048_e0': 0.000280615915959131, 'EX_cpd00793_e0': 0.000280615915959131, 'EX_cpd00058_e0': 0.00028061591595913103, 
            'EX_cpd00107_e0': 0.0375388847540127, 'EX_cpd00119_e0': 0.00792636000737159, 'EX_cpd00156_e0': 0.035223318909181824, 'EX_cpd00034_e0': 0.000280615915959131, 'EX_cpd00215_e0': 0.000280615915959131, 
            'EX_cpd00166_e0': 5.3065904751139414e-20, 'EX_cpd00017_e0': 0.001964311411713922, 'EX_cpd00205_e0': 0.0002806159159591311, 'EX_cpd00277_e0': 0.00205355085202053, 'EX_cpd00220_e0': 0.0008418477478773926, 
            'EX_cpd00322_e0': 0.024179851033723505, 'EX_cpd00028_e0': 0.00028061591595913103}
    }, 'Variovorax_CF313_pacbio_v2.RAST.fbamodel': {
        'media': {
            'EX_cpd00307_e0': 0.02097774605799387, 'EX_cpd00051_e0': 0.024669682274177707, 'EX_cpd00136_e0': 0.00028061591595913114, 'EX_cpd00644_e0': 0.0005612318319182216, 'EX_cpd00393_e0': 0.0008418477478773947, 
            'EX_cpd00149_e0': 0.0002806159159591311, 'EX_cpd00030_e0': 0.00028061591595913103, 'EX_cpd00063_e0': 0.00028061591595913103, 'EX_cpd00042_e0': 0.008456496968442185, 'EX_cpd00066_e0': 0.015451949003134522, 
            'EX_cpd00099_e0': 0.0002806159159591311, 'EX_cpd00794_e0': 0.8176244301390609, 'EX_cpd00254_e0': 0.00028061591595913114, 'EX_cpd00209_e0': 0.5366108058195971, 'EX_cpd00007_e0': 0.0007015397898978277, 
            'EX_cpd00104_e0': 0.0002806159159591311, 'EX_cpd00065_e0': 0.004720191914502181, 'EX_cpd10515_e0': 0.0008418477478773931, 'EX_cpd00069_e0': 0.012067660460661203, 'EX_cpd00048_e0': 0.0002806159159591311, 
            'EX_cpd00793_e0': 0.00028061591595913103, 'EX_cpd00058_e0': 0.0002806159159591311, 'EX_cpd00107_e0': 0.03753888475401271, 'EX_cpd00119_e0': 0.007926360007371592, 'EX_cpd00156_e0': 0.03522331890916249, 
            'EX_cpd00034_e0': 0.00028061591595913103, 'EX_cpd00215_e0': 0.00028061591595913103, 'EX_cpd00017_e0': 0.029445529353508686, 'EX_cpd00205_e0': 0.0002806159159591311, 'EX_cpd00355_e0': 0.08097454708687352, 
            'EX_cpd00220_e0': 0.000841847747877287, 'EX_cpd00322_e0': 0.02417985103372351, 'EX_cpd00028_e0': 0.0002806159159591311}
    }, 'Caulobacter_AP07_pacbio_v2.RAST.fbamodel': {
        'media': {
            'EX_cpd00039_e0': 0.028543802049017908, 'EX_cpd00118_e0': 0.00028061591595913103, 'EX_cpd00051_e0': 0.024669682270134104, 'EX_cpd00009_e0': 0.08097440804255092, 'EX_cpd00644_e0': 0.0005612318319182962, 
            'EX_cpd00393_e0': 0.0008418477478773846, 'EX_cpd00149_e0': 0.0002806159159591311, 'EX_cpd00030_e0': 0.0002806159159591311, 'EX_cpd00063_e0': 0.0002806159159591311, 'EX_cpd00066_e0': 0.015451949003134501, 
            'EX_cpd00099_e0': 0.00028061591595913103, 'EX_cpd00794_e0': 0.010004239084357764, 'EX_cpd03847_e0': 0.0025010597710894405, 'EX_cpd00254_e0': 0.00028061591595913103, 'EX_cpd00264_e0': 0.00028061591595913103, 
            'EX_cpd00007_e0': 1.0910057966381945, 'EX_cpd00104_e0': 0.00028061591595913103, 'EX_cpd01080_e0': 0.024916275954454083, 'EX_cpd00065_e0': 0.00472019191450218, 'EX_cpd10515_e0': 0.0008418477478773931, 
            'EX_cpd00069_e0': 0.012067660460661201, 'EX_cpd00048_e0': 0.00028061591595913103, 'EX_cpd00793_e0': 0.00028061591595912485, 'EX_cpd00058_e0': 0.00028061591595913103, 'EX_cpd00107_e0': 0.0375388847540127, 
            'EX_cpd00076_e0': 0.19340178407835312, 'EX_cpd00119_e0': 0.11437788733137857, 'EX_cpd00156_e0': 0.03522331890916249, 'EX_cpd00034_e0': 0.0002806159159591311, 'EX_cpd00215_e0': 0.0002806159159591311, 
            'EX_cpd00092_e0': 0.020977676537344135, 'EX_cpd00017_e0': 0.02944545983006225, 'EX_cpd00084_e0': 0.008456496968442268, 'EX_cpd00205_e0': 0.00028061591595913103, 'EX_cpd00220_e0': 0.0008418477478773931, 
            'EX_cpd00322_e0': 0.024179851033723502, 'EX_cpd00028_e0': 0.00028061591595913103}
    }, 'Duagnella_sp_CF402.RAST.fbamodel': {
        'media': {
            'EX_cpd00184_e0': 0.0011885753734127407, 'EX_cpd00030_e0': 0.00028061591595913103, 'EX_cpd00039_e0': 0.0433858040038226, 'EX_cpd00149_e0': 0.00028061591595913103, 'EX_cpd00381_e0': 0.00310578482038375, 
            'EX_cpd00065_e0': 0.004720191914502181, 'EX_cpd00041_e0': 0.22032752034499845, 'EX_cpd00118_e0': 0.00252554324363218, 'EX_cpd00060_e0': 0.04906066438799808, 'EX_cpd00018_e0': 0.04764482340519846, 
            'EX_cpd00027_e0': 0.4310032679453922, 'EX_cpd00063_e0': 0.00028061591595913103, 'EX_cpd00069_e0': 0.012909508208538596, 'EX_cpd00023_e0': 0.05998681321711485, 'EX_cpd00048_e0': 0.00028061591595913103, 
            'EX_cpd00793_e0': 0.00028061591595913114, 'EX_cpd00058_e0': 0.0002806159159591312, 'EX_cpd00205_e0': 0.00028061591595913103, 'EX_cpd00051_e0': 0.024669682270134104, 'EX_cpd00161_e0': 0.021107273278056907, 
            'EX_cpd00054_e0': 0.02330509711956831, 'EX_cpd00066_e0': 0.015451949003134504, 'EX_cpd00107_e0': 0.03753888475401271, 'EX_cpd00239_e0': 0.014842001954804677, 'EX_cpd00119_e0': 0.007926360007371592, 
            'EX_cpd00099_e0': 0.00028061591595913103, 'EX_cpd00156_e0': 0.035223318909162506, 'EX_cpd00218_e0': 0.0005612318319179656, 'EX_cpd00046_e0': 0.00841036156544863, 'EX_cpd00034_e0': 0.0002806159159591312, 
            'EX_cpd00644_e0': 0.000561231831918312, 'EX_cpd00254_e0': 0.0002806159159591312, 'EX_cpd00220_e0': 0.0008418477478773935, 'EX_cpd00033_e0': 0.053512521942736, 'EX_cpd00215_e0': 0.00028061591595913114, 
            'EX_cpd00129_e0': 0.018435466533999103, 'EX_cpd00322_e0': 0.024179851033723505, 'EX_cpd00091_e0': 0.009363806406643655, 'EX_cpd00007_e0': 0.6690175306204083, 'EX_cpd00028_e0': 0.0002806159159591312, 
            'EX_cpd00035_e0': 0.28910683631288886, 'EX_cpd00654_e0': 0.0020151318325515315, 'EX_cpd10516_e0': 0.0008418477478773932, 'EX_cpd00393_e0': 0.0008418477478773932, 'EX_cpd00126_e0': 0.015555813952923834}
    }, 'Burkholderia_sp._BT03.RAST.fbamodel': {
        'media': {
            'EX_cpd00039_e0': 0.028543802049017908, 'EX_cpd00051_e0': 0.024669682270134104, 'EX_cpd00136_e0': 0.00028061591595913103, 'EX_cpd00218_e0': 0.0005612318319184721, 'EX_cpd00644_e0': 0.0005612318319182858, 
            'EX_cpd00393_e0': 0.000841847747877396, 'EX_cpd00149_e0': 0.0002806159159591311, 'EX_cpd00030_e0': 0.00028061591595913103, 'EX_cpd00063_e0': 0.00028061591595913103, 'EX_cpd00042_e0': 0.008456496968442256, 
            'EX_cpd00066_e0': 0.015451949003134503, 'EX_cpd00099_e0': 0.00028061591595913103, 'EX_cpd00794_e0': 0.010004239084357762, 'EX_cpd00254_e0': 0.00028061591595913114, 'EX_cpd00264_e0': 0.0002806159159591311, 
            'EX_cpd00209_e0': 0.711225246799786, 'EX_cpd00007_e0': 0.0008418477478773931, 'EX_cpd00104_e0': 0.00028061591595913103, 'EX_cpd00065_e0': 0.004720191914502181, 'EX_cpd10515_e0': 0.0005612318319182621, 
            'EX_cpd00069_e0': 0.012067660460661203, 'EX_cpd00080_e0': 0.08097487154922646, 'EX_cpd00048_e0': 0.0002806159159591311, 'EX_cpd00793_e0': 0.00028061591595913196, 'EX_cpd00058_e0': 0.0002806159159591311, 
            'EX_cpd00107_e0': 0.03753888475401271, 'EX_cpd00119_e0': 0.007926360007371592, 'EX_cpd00156_e0': 0.035223318909162506, 'EX_cpd00034_e0': 0.0002806159159591311, 'EX_cpd00215_e0': 0.0002806159159591311, 
            'EX_cpd00179_e0': 0.9801612844546076, 'EX_cpd00017_e0': 0.02944569158220573, 'EX_cpd00205_e0': 0.0002806159159591311, 'EX_cpd00220_e0': 0.0008418477478773936, 'EX_cpd00322_e0': 0.02417985103372351, 
            'EX_cpd00028_e0': 0.0002806159159591311, 'EX_cpd10516_e0': 0.00028061591595913103}
    }, 'Pseudomonas_GM17_pacbio_v2.RAST.fbamodel': {
        'media': {
            'EX_cpd01017_e0': 0.008456496968442409, 'EX_cpd00307_e0': 0.008410361565448618, 'EX_cpd00051_e0': 0.0246696822701341, 'EX_cpd00136_e0': 0.00028061591595913103, 'EX_cpd00644_e0': 0.0005612318319182493, 
            'EX_cpd00654_e0': 0.005215640721434261, 'EX_cpd00393_e0': 0.0008418477478773933, 'EX_cpd00149_e0': 0.00028061591595913103, 'EX_cpd00030_e0': 0.0002806159159591311, 'EX_cpd00063_e0': 0.0002806159159591311, 
            'EX_cpd00066_e0': 0.015451949003134503, 'EX_cpd00099_e0': 0.00028061591595913103, 'EX_cpd03847_e0': 0.002501059771089441, 'EX_cpd00254_e0': 0.00028061591595913103, 'EX_cpd00264_e0': 0.00028061591595913103, 
            'EX_cpd00209_e0': 0.4491414728734128, 'EX_cpd00007_e0': 0.0008418477478773933, 'EX_cpd00104_e0': 0.00028061591595922915, 'EX_cpd00116_e0': 9.806511349084751e-17, 'EX_cpd01080_e0': 0.024916275954454094, 
            'EX_cpd00065_e0': 0.00472019191450218, 'EX_cpd10515_e0': 0.0008418477478773932, 'EX_cpd00069_e0': 0.012067660460661201, 'EX_cpd00048_e0': 0.00028061591595913103, 'EX_cpd00793_e0': 0.000280615915959131, 
            'EX_cpd00058_e0': 0.00028061591595913103, 'EX_cpd00107_e0': 0.03753888475401271, 'EX_cpd00119_e0': 0.007926360007371592, 'EX_cpd00156_e0': 0.03522331890923616, 'EX_cpd00034_e0': 0.00028061591595913103, 
            'EX_cpd00215_e0': 0.00028061591595913103, 'EX_cpd00179_e0': 0.06325298447088548, 'EX_cpd00017_e0': 0.01306075817503565, 'EX_cpd00205_e0': 0.00028061591595913103, 'EX_cpd00355_e0': 1.186523527072758, 
            'EX_cpd00438_e0': 0.0011917803122624656, 'EX_cpd00220_e0': 0.000841847747877392, 'EX_cpd00322_e0': 0.0241798510337235, 'EX_cpd00028_e0': 0.00028061591595913103, 'EX_cpd00311_e0': 0.0151931232964184}}
}

# %%
RAST_genomes = {}
for model in pmi_models:
    info = kbase_api.get_object_info_from_ref(model.genome_ref)
    RAST_genomes[model.id] = (kbase_api.get_object(info.id, info.workspace_id))

# %%
genome1, genome2 = list(RAST_genomes.values())[:2]
print(set([list(content["SSO"].keys())[0] for dic in genome1["cdss"] for x, content in dic.items() if x == "ontology_terms" and len(content["SSO"].keys()) > 0]) == set([
    list(content["SSO"].keys())[0] for dic in genome2["cdss"] for x, content in dic.items() if x == "ontology_terms" and len(content["SSO"].keys()) > 0]))

genome2_terms = []
for dic in genome2["cdss"]:
    for sso in dic["ontology_terms"]["SSO"].keys():
        genome2_terms.append(sso)
        
genome1_terms = []
for dic in genome1["cdss"]:
    for sso in dic["ontology_terms"]["SSO"].keys():
        genome1_terms.append(sso)
        
print(genome1_terms == genome2_terms)
# for genome in RAST_genomes.values():
#     print(set(list(content["SSO"].keys())[0] for dic in genome["cdss"] for x, content in dic.items() if x == "ontology_terms" and len(content["SSO"].keys()) > 0))
#     break
# Out:
# True
# True

# %%
# genome = kbase_api.get_from_ws(CF313.genome_ref)
[term.ontology_terms for term in genome.cdss]
# print(genome.cdss[3].ontology_terms)
# Out:
# [{},
#  {},
#  {},
#  {},
#  {},
#  {},
#  {},
#  {},
#  {},
#  {},
#  {},
#  {},
#  {},
#  {},
#  {},
#  {},
#  {},
#  {},
#  {},
#  {},
#  {},
#  {},
#  {},
#  {},
#  {},
#  {},
#  {},
#  {},
#  {},
#  {},
#  {},
#  {},
#  {},
#  {},
#  {},
#  {},
#  {},
#  {},
#  {},
#  {},
#  {},
#  {},
#  {},
#  {},
#  {},
#  {},
#  {},
#  {},
#  {},
#  {},
#  {},
#  {},
#  {},
#  {},
#  {},
#  {},
#  {},
#  {},
#  {},
#  {},
#  {},
#  {},
#  {},
#  {},
#  {},
#  {},
#  {},
#  {},
#  {},
#  {},
#  {},
#  {},
#  {},
#  {},
#  {},
#  {},
#  {},
#  {},
#  {},
#  {},
#  {},
#  {},
#  {},
#  {},
#  {},
#  {},
#  {},
#  {},
#  {},
#  {},
#  {},
#  {},
#  {},
#  {},
#  {},
#  {},
#  {},
#  {},
#  {},
#  {},
#  {},
#  {},
#  {},
#  {},
#  {},
#  {},
#  {},
#  {},
#  {},
#  {},
#  {},
#  {},
#  {},
#  {},
#  {},
#  {},
#  {},
#  {},
#  {},
#  {},
#  {},
#  {},
#  {},
#  {},
#  {},
#  {},
#  {},
#  {},
#  {},
#  {},
#  {},
#  {},
#  {},
#  {},
#  {},
#  {},
#  {},
#  {},
#  {},
#  {},
#  {},
#  {},
# ...

# %%
# %run ../../../modelseedpy/community/mssmetana.py

import os
local_cobrakbase_path = os.path.join('C:', 'Users', 'Andrew Freiburger','Documents','Argonne','cobrakbase')
os.environ["HOME"] = local_cobrakbase_path

# import the KBase
import cobrakbase
# with open("/Users/afreiburger/Documents/kbase_token.txt") as token_file:
with open("D:/Users/Andrew Freiburger/Documents/Argonne/kbase_token.txt") as token_file:
    kbase_api = cobrakbase.KBaseAPI(token_file.readline())

GCF_001421425 = kbase_api.get_from_ws("136582/517/1")
GCF_001421355 = kbase_api.get_from_ws("136582/407/1")
r2a_media = kbase_api.get_from_ws("136582/402/1")

# RAST_genomes = {"GCF_001421425": GCF_001421425, "GCF_001421355": GCF_001421355}
models = [GCF_001421425, GCF_001421355]
# MSSmetana.rfc(models, kbase_object=kbase_api)
# Out:
# cobrakbase 0.3.1

# %%
# %run ../../../modelseedpy/community/mssmetana.py
output = MSSmetana.mip(member_models=models, environment=r2a_media, costless=True)
# Out:
# ['EX_cpd00067_e0', 'EX_cpd00129_e0', 'EX_cpd00009_e0', 'EX_cpd00075_e0', 'EX_cpd00218_e0', 'EX_cpd00122_e0', 'EX_cpd00159_e0', 'EX_cpd00001_e0', 'EX_cpd00033_e0', 'EX_cpd00011_e0', 'EX_cpd00012_e0', 'EX_cpd00024_e0', 'EX_cpd03279_e0', 'EX_cpd00041_e0', 'EX_cpd00246_e0', 'EX_cpd00100_e0', 'EX_cpd00182_e0'] ['EX_cpd10515_e0', 'EX_cpd00794_e0', 'EX_cpd00166_e0', 'EX_cpd00067_e0', 'EX_cpd00161_e0', 'EX_cpd00069_e0', 'EX_cpd00118_e0', 'EX_cpd00311_e0', 'EX_cpd00053_e0', 'EX_cpd00027_e0', 'EX_cpd00654_e0', 'EX_cpd00132_e0', 'EX_cpd00075_e0', 'EX_cpd00107_e0', 'EX_cpd00128_e0', 'EX_cpd00060_e0', 'EX_cpd00054_e0', 'EX_cpd00039_e0', 'EX_cpd00066_e0', 'EX_cpd00276_e0', 'EX_cpd00136_e0', 'EX_cpd00084_e0', 'EX_cpd00024_e0', 'EX_cpd00080_e0', 'EX_cpd00307_e0', 'EX_cpd00051_e0', 'EX_cpd00106_e0', 'EX_cpd00119_e0', 'EX_cpd00268_e0', 'EX_cpd15560_e0']

# %%
output
# Out:
# (['EX_cpd00067_e0', 'EX_cpd00075_e0', 'EX_cpd00024_e0'], 3)

# %%
import re
print(re.sub("(root\[|\])","",output[0][0]))
print(dir(output[0][0]))
# Out:
# 'EX_cpd00654_e0'
# ['__add__', '__class__', '__contains__', '__delattr__', '__dir__', '__doc__', '__eq__', '__format__', '__ge__', '__getattribute__', '__getitem__', '__getnewargs__', '__gt__', '__hash__', '__init__', '__init_subclass__', '__iter__', '__le__', '__len__', '__lt__', '__mod__', '__mul__', '__ne__', '__new__', '__reduce__', '__reduce_ex__', '__repr__', '__rmod__', '__rmul__', '__setattr__', '__sizeof__', '__str__', '__subclasshook__', 'capitalize', 'casefold', 'center', 'count', 'encode', 'endswith', 'expandtabs', 'find', 'format', 'format_map', 'index', 'isalnum', 'isalpha', 'isascii', 'isdecimal', 'isdigit', 'isidentifier', 'islower', 'isnumeric', 'isprintable', 'isspace', 'istitle', 'isupper', 'join', 'ljust', 'lower', 'lstrip', 'maketrans', 'partition', 'removeprefix', 'removesuffix', 'replace', 'rfind', 'rindex', 'rjust', 'rpartition', 'rsplit', 'rstrip', 'split', 'splitlines', 'startswith', 'strip', 'swapcase', 'title', 'translate', 'upper', 'zfill']

# %%
# %%time

# %run ../../../modelseedpy/community/mssmetana.py

# genomes = MSSmetana.get_all_genomes_from_ws(136582, kbase_api)
# genome_similarities = MSSmetana.RAST_functionality(genomes)
import os

df, mets = MSSmetana.kbase_output(pmi_models, 
                                  mem_media=PMI_models_media, 
                                  pairs=negative_interactions, environment=r2a_media, kbase_obj=kbase_api, 
                                  # lazy_load=True, 
                                  pool_size=os.cpu_count()/4
                                  #RAST_genomes=RAST_genomes
                                 )
# Out:
# Examining the 8 model pairs
# Loading 16 workers and computing the scores 2023-04-12 16:15:32.595590
# CPU times: total: 8.08 s
# Wall time: 1min 17s
# C:\Users\Andrew Freiburger\AppData\Local\Programs\Python\Python39\lib\site-packages\multiprocess\pool.py:265: ResourceWarning: unclosed running multiprocessing pool <multiprocess.pool.Pool state=RUN pool_size=16>
#   _warn(f"unclosed running multiprocessing pool {self!r}",
# ...

# %%
# %%time

# %run ../../../modelseedpy/community/mssmetana.py

# genomes = MSSmetana.get_all_genomes_from_ws(136582, kbase_api)
# genome_similarities = MSSmetana.RAST_functionality(genomes)
import os

df, mets = MSSmetana.kbase_output(pmi_models, 
                                  mem_media=PMI_models_media, 
                                  pairs=negative_interactions, environment=r2a_media, kbase_obj=kbase_api, 
                                  # lazy_load=True, 
                                  # pool_size=os.cpu_count()/8
                                  #RAST_genomes=RAST_genomes
                                 )
# Out:
# Examining the 8 model pairs
# MainProcess~~0	['Pseudomonas_GM17_pacbio_v2.RAST.fbamodel', 'Bacillus_sp._bc15.RAST.fbamodel']	MRO done	MIP done	GRD done
# MainProcess~~1	['Pseudomonas_GM17_pacbio_v2.RAST.fbamodel', 'Sphingobium_AP49_pacbio_v2.RAST.fbamodel']	MRO done	MIP done	GRD done
# MainProcess~~2	['Pseudomonas_GM17_pacbio_v2.RAST.fbamodel', 'Variovorax_CF313_pacbio_v2.RAST.fbamodel']	MRO done	MIP done	GRD done
# MainProcess~~3	['Pseudomonas_GM17_pacbio_v2.RAST.fbamodel', 'Caulobacter_AP07_pacbio_v2.RAST.fbamodel']	MRO done	MIP done	GRD done
# MainProcess~~4	['Pseudomonas_GM17_pacbio_v2.RAST.fbamodel', 'Duagnella_sp_CF402.RAST.fbamodel']	MRO done	MIP done	GRD done
# MainProcess~~5	['Pseudomonas_GM17_pacbio_v2.RAST.fbamodel', 'Burkholderia_sp._BT03.RAST.fbamodel']	MRO done	MIP done	GRD done
# MainProcess~~6	['Variovorax_CF313_pacbio_v2.RAST.fbamodel', 'Burkholderia_sp._BT03.RAST.fbamodel']	MRO done	MIP done	GRD done
# ...

# %% [markdown]
# ## Various media comparison

# %%
r2a_media = kbase_api.get_from_ws("136582/402/1")
mops_glucose = kbase_api.get_from_ws("136582/1204/1")
biolog_lac_asp = kbase_api.get_from_ws("136582/1203/1")
glucose = kbase_api.get_from_ws("122814/65/1")
minGlucose = kbase_api.get_from_ws("122814/64/1")
fructose = kbase_api.get_from_ws("122814/66/1")
maltose = kbase_api.get_from_ws("122814/67/1")

media = [r2a_media, mops_glucose, biolog_lac_asp, glucose, minGlucose, fructose, maltose]

# %%
# %run ../../../modelseedpy/community/mssmetana.py

many_media_df, many_media_mets = MSSmetana.kbase_output(pmi_models, mem_media=PMI_models_media, pairs=negative_interactions, environments=media, kbase_obj=kbase_api)
# Out:
# Examining the 8 model pairs
# The minimal flux media consists of 39 compounds and a 1.947779241097335 total influx, with a growth value of 0.10000000000007365
# The minimal flux media consists of 36 compounds and a 1.4912990953810796 total influx, with a growth value of 0.10000000000006555
# MainProcess~~0	['Pseudomonas_GM17_pacbio_v2.RAST.fbamodel', 'Bacillus_sp._bc15.RAST.fbamodel']
# 	Environment0: <cobrakbase.core.kbasebiochem.media.Media object at 0x000001A2BC1201F0>	MRO done	MIP done	CIP done	GYD done
# 	Environment1: <cobrakbase.core.kbasebiochem.media.Media object at 0x000001A2BC1209A0>	MRO done	MIP done	CIP done	GYD done
# 	Environment2: <cobrakbase.core.kbasebiochem.media.Media object at 0x000001A2BC0A6220>	MRO done	MIP done	CIP done	GYD done
# 	Environment3: <cobrakbase.core.kbasebiochem.media.Media object at 0x000001A2BC120280>	MRO done	MIP done	CIP done	GYD done
# ...

# %%
many_media_df.to_csv("many_media_sampling.csv")

# %%
# %run ../../../modelseedpy/core/report.py

reportHTML = smetana_report(many_media_df, many_media_mets, "many_media_sampling.html")

# %% [markdown]
# # CIP method comparison

# %% [markdown]
# ### Aggregate compounds

# %%
# %run ../../../modelseedpy/community/mssmetana.py

costless_mets, num_costless_mets = MSSmetana.cip(member_models=models)
print(costless_mets, num_costless_mets)
# Out:
# {'EX_cpd00060_e0', 'EX_cpd00142_e0', 'EX_cpd00036_e0', 'EX_cpd00067_e0', 'EX_cpd00246_e0', 'EX_cpd00033_e0', 'EX_cpd00035_e0', 'EX_cpd00082_e0', 'EX_cpd00122_e0', 'EX_cpd00012_e0', 'EX_cpd00053_e0', 'EX_cpd00013_e0', 'EX_cpd00047_e0', 'EX_cpd00249_e0', 'EX_cpd00009_e0', 'EX_cpd00159_e0', 'EX_cpd00075_e0', 'EX_cpd00023_e0', 'EX_cpd00041_e0', 'EX_cpd00794_e0', 'EX_cpd03279_e0', 'EX_cpd00218_e0', 'EX_cpd00011_e0', 'EX_cpd00129_e0'} 24

# %% [markdown]
# ### Subset of MIP

# %%
# %run ../../../modelseedpy/community/mssmetana.py

mip_costless_mets, num_mip_costless_mets = MSSmetana.mip(member_models=models, costless=True)
print(mip_costless_mets, num_mip_costless_mets)
# Out:
# ['EX_cpd00067_e0', 'EX_cpd00053_e0', 'EX_cpd00060_e0', 'EX_cpd00794_e0'] 4

# %% [markdown]
# ### Additional scores

# %%
# %run ../../../modelseedpy/community/mssmetana.py

outputs = MSSmetana.mip(member_models=models, costless=True, pc=True, multi_output=True)
print(outputs)
# Out:
# [(['EX_cpd00067_e0', 'EX_cpd00119_e0', 'EX_cpd00137_e0', 'EX_cpd00118_e0', 'EX_cpd00132_e0', 'EX_cpd00051_e0', 'EX_cpd00027_e0', 'EX_cpd00311_e0', 'EX_cpd00036_e0', 'EX_cpd00161_e0', 'EX_cpd00024_e0', 'EX_cpd00069_e0', 'EX_cpd00164_e0', 'EX_cpd00054_e0', 'EX_cpd00136_e0', 'EX_cpd00053_e0', 'EX_cpd00107_e0', 'EX_cpd00066_e0', 'EX_cpd00039_e0', 'EX_cpd00084_e0', 'EX_cpd00276_e0', 'EX_cpd00128_e0', 'EX_cpd00307_e0', 'EX_cpd00166_e0', 'EX_cpd00794_e0', 'EX_cpd00654_e0', 'EX_cpd00106_e0', 'EX_cpd15560_e0', 'EX_cpd00001_e0', 'EX_cpd00060_e0', 'EX_cpd00080_e0'], 31), (['EX_cpd00067_e0', 'EX_cpd00036_e0', 'EX_cpd00053_e0', 'EX_cpd00794_e0', 'EX_cpd00060_e0'], 5), 0.4773145712781245]

# %%
outputs
# Out:
# [(['EX_cpd00067_e0',
#    'EX_cpd00119_e0',
#    'EX_cpd00137_e0',
#    'EX_cpd00118_e0',
#    'EX_cpd00132_e0',
#    'EX_cpd00051_e0',
#    'EX_cpd00027_e0',
#    'EX_cpd00311_e0',
#    'EX_cpd00036_e0',
#    'EX_cpd00161_e0',
#    'EX_cpd00024_e0',
#    'EX_cpd00069_e0',
#    'EX_cpd00164_e0',
#    'EX_cpd00054_e0',
#    'EX_cpd00136_e0',
#    'EX_cpd00053_e0',
#    'EX_cpd00107_e0',
#    'EX_cpd00066_e0',
#    'EX_cpd00039_e0',
#    'EX_cpd00084_e0',
#    'EX_cpd00276_e0',
#    'EX_cpd00128_e0',
#    'EX_cpd00307_e0',
#    'EX_cpd00166_e0',
#    'EX_cpd00794_e0',
#    'EX_cpd00654_e0',
#    'EX_cpd00106_e0',
#    'EX_cpd15560_e0',
#    'EX_cpd00001_e0',
#    'EX_cpd00060_e0',
#    'EX_cpd00080_e0'],
#   31),
#  (['EX_cpd00067_e0',
#    'EX_cpd00036_e0',
#    'EX_cpd00053_e0',
#    'EX_cpd00794_e0',
#    'EX_cpd00060_e0'],
#   5),
#  0.4773145712781245]

# %% [markdown]
# ### Debug the KBase_output

# %%
GCF_001422165 = kbase_api.get_from_ws("136582/695/1") ; GCF_001423965 = kbase_api.get_from_ws("136582/601/1") ; GCF_001424505 = kbase_api.get_from_ws("136582/509/1") ; GCF_001421245 = kbase_api.get_from_ws("136582/437/1")
print("row1", end="\r")
GCF_001424455 = kbase_api.get_from_ws("136582/683/1") ; GCF_001422325 = kbase_api.get_from_ws("136582/605/1") ; GCF_001422815 = kbase_api.get_from_ws("136582/611/1") ; GCF_001424185 = kbase_api.get_from_ws("136582/834/1")
# Out:
# row1

# %%
models = [GCF_001422165, GCF_001423965, GCF_001424505, GCF_001421245, GCF_001424455, GCF_001422325, GCF_001422815, GCF_001424185]

# %%
# %run ../../../modelseedpy/community/mssmetana.py

from os import cpu_count

outputs = MSSmetana.kbase_output(models, environments=r2a_media, kbase_obj=kbase_api, costless=True, pc=True, 
                                 # pool_size=cpu_count()/2
                                )
print(outputs)
# Out:
# The minimal flux media consists of 38 compounds and a 1.9202602818224825 total influx, with a growth value of 0.09999999999984148
# The minimal flux media consists of 44 compounds and a 4.151288539454804 total influx, with a growth value of 0.10000000000123677
# The minimal media of all members:
# ...

# %% [markdown]
# # Statistically process the above results

# %% [markdown]
# ## MRO scores

# %% [markdown]
# ### Parsed MRO values

# %%
# from scipy import stats
# posInteractions = [YR343_CF313.mro[0], AP49_BC15.mro[0], YR343_CF313.mro[0], YR343_CF313.mro[0]]
# negInteractions = [0.8636363636363636, 0.9, 0.9473684210526315, 0.7727272727272727, 0.8636363636363636, 0.8181818181818182, 0.8181818181818182, 0.8181818181818182, 0.8]

# ttest = stats.ttest_ind(posInteractions, negInteractions)
# print(ttest.pvalue)

# %%
from scipy import stats
posInteractions = [1, 0.7619047619047619, 0.38636363636363635, 0.36363636363636365]
negInteractions = [0.8636363636363636, 0.9, 0.9473684210526315, 0.7727272727272727, 0.8636363636363636, 0.8181818181818182, 0.8181818181818182, 0.8181818181818182, 0.8]

ttest = stats.ttest_ind(posInteractions, negInteractions)
print(ttest.pvalue)

# %%
from matplotlib import pyplot
import sigfig

pyplot.rc('axes', titlesize=20, labelsize=20)
pyplot.rc('xtick', labelsize=20)
pyplot.rc('ytick', labelsize=20)
pyplot.rc('legend', fontsize=18)
fig = pyplot.figure(figsize=(7,10))

pyplot.boxplot([posInteractions, negInteractions], labels=["'+'", "'--'"])
pyplot.scatter([1]*len(posInteractions), posInteractions)
pyplot.scatter([2]*len(negInteractions), negInteractions)
pyplot.xlabel("Interaction type")
pyplot.ylabel("MRO score (overlap)")
pyplot.text(1.6,.7, f"p-value: {sigfig.round(ttest.pvalue, sigfigs=3)}", fontsize="x-large")
fig.savefig("parsed MRO comparion.jpg")
# display(fig)
# pyplot.show()

# %% [markdown]
# ### Averaged MRO values

# %%
from scipy import stats
posInteractions = [0.9444444444444444, 0.7804878048780488, 0.5396825396825397, 0.53125]
negInteractions = [0.9047619047619048, 0.8780487804878049, 0.9473684210526315]
negInteractions2 = [0.8095238095238095, 0.926829268292683, 0.9473684210526315, 0.926829268292683, 0.8095238095238095, 0.5757575757575758, 0.8780487804878049]
posInteractions2 = [0.9444444444444444, 0.7804878048780488, 0.5396825396825397, 0.53125]

ttest = stats.ttest_ind(posInteractions2, negInteractions2)
print(ttest.pvalue)

# %%
from matplotlib import pyplot
import sigfig

pyplot.rc('axes', titlesize=20, labelsize=20)
pyplot.rc('xtick', labelsize=20)
pyplot.rc('ytick', labelsize=20)
pyplot.rc('legend', fontsize=18)
fig = pyplot.figure(figsize=(7,10))

pyplot.boxplot([posInteractions2, negInteractions2], labels=["'+'", "'--'"])
pyplot.scatter([1]*len(posInteractions2), posInteractions2)
pyplot.scatter([2]*len(negInteractions2), negInteractions2)
pyplot.xlabel("Interaction type")
pyplot.ylabel("MRO score (overlap)")
pyplot.text(1.6,.7, f"p-value: {sigfig.round(ttest.pvalue, sigfigs=3)}", fontsize="x-large")
fig.savefig("MRO comparion.jpg")
# display(fig)
# pyplot.show()

# %% [markdown]
# ## MIP scores

# %%
from scipy import stats
# posInteractions =[YR343_CF313.mip, AP49_BC15.mip, CF402_CF313.mip, CF402_BC15.mip]
# negInteractions = [GM17_BC15.mip, AP07_AP49.mip, CF313_BT03.mip, GM17_AP49.mip, GM17_CF313.mip, GM17_AP07.mip, GM17_CF402.mip, GM17_BT03.mip, CF402_BC15.mip]
negInteractions = [0, 0, 0, 0, 1, 4, 0]
posInteractions = [0, 1, 6, 7]

ttest = stats.ttest_ind(posInteractions, negInteractions)
print(ttest.pvalue)

# %%
from matplotlib import pyplot
import sigfig

pyplot.rc('axes', titlesize=20, labelsize=20)
pyplot.rc('xtick', labelsize=20)
pyplot.rc('ytick', labelsize=20)
pyplot.rc('legend', fontsize=18)
fig = pyplot.figure(figsize=(7,10))

pyplot.boxplot([posInteractions, negInteractions], labels=["'+'", "'--'"])
pyplot.scatter([1]*len(posInteractions), posInteractions)
pyplot.scatter([2]*len(negInteractions), negInteractions)
pyplot.xlabel("Interaction type")
pyplot.ylabel("MIP score (syntrophy)")
pyplot.text(1.6,2, f"p-value: {sigfig.round(ttest.pvalue, sigfigs=3)}", fontsize="x-large")
fig.savefig("MIP comparion.jpg")
# display(fig)
# pyplot.show()

# %% [markdown]
# ## smetana score

# %%
from scipy import stats
posInteractions = [63.57, 47.18, 52.63, 46, 32, 38, 0, 0]
negInteractions = [53, 48.1, 44.76, 45, 0, 0]

ttest = stats.ttest_ind(posInteractions, negInteractions)
print(ttest.pvalue)

# %%
from matplotlib import pyplot
import sigfig

pyplot.rc('axes', titlesize=20, labelsize=20)
pyplot.rc('xtick', labelsize=20)
pyplot.rc('ytick', labelsize=20)
pyplot.rc('legend', fontsize=18)
fig = pyplot.figure(figsize=(7,10))

pyplot.boxplot([posInteractions, negInteractions], labels=["'+'", "'--'"])
pyplot.scatter([1]*len(posInteractions), posInteractions)
pyplot.scatter([2]*len(negInteractions), negInteractions)
pyplot.xlabel("Interaction type")
pyplot.ylabel("smetana score (syntrophy potential)")
pyplot.text(1.6,62, f"p-value: {sigfig.round(ttest.pvalue, sigfigs=3)}", fontsize="x-large")
fig.savefig("smetana comparion.jpg")
# display(fig)
# pyplot.show()

# %% [markdown]
# # Combined SMETANA report statistics

# %%
from pandas import read_csv
# combined_df = read_csv("combined_smetana_report.csv").drop(["Unnamed: 0"], axis=1)
combined_df = read_csv("all_v_all_smetana.csv").drop(["Unnamed: 0"], axis=1)
combined_df
# Out:
#                               model1                         model2  \
# 0      GCF_001422165.1.RAST.fbamodel  GCF_001423965.1.RAST.fbamodel
# 1      GCF_001422165.1.RAST.fbamodel  GCF_001424505.1.RAST.fbamodel
# 2      GCF_001422165.1.RAST.fbamodel  GCF_001421245.1.RAST.fbamodel
# 3      GCF_001422165.1.RAST.fbamodel  GCF_001424455.1.RAST.fbamodel
# 4      GCF_001422165.1.RAST.fbamodel  GCF_001422325.1.RAST.fbamodel
# ...                              ...                            ...
# 16466  GCF_920984695.1.RAST.fbamodel  GCF_001422775.1.RAST.fbamodel
# 16467  GCF_920984695.1.RAST.fbamodel  GCF_001421995.1.RAST.fbamodel
# 16468  GCF_001422455.1.RAST.fbamodel  GCF_001422775.1.RAST.fbamodel
# 16469  GCF_001422455.1.RAST.fbamodel  GCF_001421995.1.RAST.fbamodel
# 16470  GCF_001422775.1.RAST.fbamodel  GCF_001421995.1.RAST.fbamodel
#
#             mro_model1       mro_model2  mip       GRD
# 0      0.65000 (26/40)  0.74286 (26/35)   13  1.665175
# ...

# %%
leaf_to_genbank = {'Leaf5': 'GCF_001421155.1', 'Leaf8': 'GCF_001421165.1', 'Leaf10': 'GCF_001421245.1', 'Leaf203': 'GCF_001421275.1', 'Leaf11': 'GCF_001421285.1', 'Leaf1': 'GCF_001421315.1', 'Leaf2': 'GCF_001421325.1', 
                   'Leaf9': 'GCF_001421355.1', 'Leaf16': 'GCF_001421405.1', 'Leaf208': 'GCF_001421415.1', 'Leaf15': 'GCF_001421425.1', 'Leaf201': 'GCF_001421435.1', 'Leaf210': 'GCF_001421485.1', 'Leaf17': 'GCF_001421505.1', 
                   'Leaf216': 'GCF_001421515.1', 'Leaf20': 'GCF_001421535.1', 'Leaf222': 'GCF_001421565.1', 'Leaf23': 'GCF_001421585.1', 'Leaf24': 'GCF_001421605.1', 'Leaf226': 'GCF_001421625.1', 'Leaf25': 'GCF_001421635.1', 
                   'Leaf26': 'GCF_001421665.1', 'Leaf28': 'GCF_001421685.1', 'Leaf220': 'GCF_001421705.1', 'Leaf22': 'GCF_001421715.1', 'Leaf230': 'GCF_001421745.1', 'Leaf32': 'GCF_001421765.1', 'Leaf33': 'GCF_001421785.1', 
                   'Leaf34': 'GCF_001421805.1', 'Leaf38': 'GCF_001421825.1', 'Leaf42': 'GCF_001421845.1', 'Leaf44': 'GCF_001421865.1', 'Leaf48': 'GCF_001421885.1', 'Leaf61': 'GCF_001421905.1', 'Leaf62': 'GCF_001421915.1', 
                   'Leaf64': 'GCF_001421945.1', 'Leaf67': 'GCF_001421965.1', 'Leaf231': 'GCF_001421995.1', 'Leaf70': 'GCF_001422025.1', 'Leaf242': 'GCF_001422045.1', 'Leaf76': 'GCF_001422065.1', 'Leaf83': 'GCF_001422075.1', 
                   'Leaf84': 'GCF_001422105.1', 'Leaf85': 'GCF_001422125.1', 'Leaf254': 'GCF_001422145.1', 'Leaf86': 'GCF_001422165.1', 'Leaf257': 'GCF_001422185.1', 'Leaf261': 'GCF_001422205.1', 'Leaf89': 'GCF_001422215.1', 
                   'Leaf262': 'GCF_001422245.1', 'Leaf263': 'GCF_001422285.1', 'Leaf264': 'GCF_001422325.1', 'Leaf93': 'GCF_001422345.1', 'Leaf265': 'GCF_001422365.1', 'Leaf99': 'GCF_001422375.1', 'Leaf267': 'GCF_001422405.1', 
                   'Leaf102': 'GCF_001422425.1', 'Leaf274': 'GCF_001422445.1', 'Leaf280': 'GCF_001422455.1', 'Leaf283': 'GCF_001422485.1', 'Leaf29': 'GCF_001422495.1', 'Leaf30': 'GCF_001422525.1', 'Leaf41': 'GCF_001422545.1', 
                   'Leaf53': 'GCF_001422605.1', 'Leaf58': 'GCF_003627215.1', 'Leaf69': 'GCF_001422645.1', 'Leaf234': 'GCF_001422665.1', 'Leaf72': 'GCF_001422685.1', 'Leaf244': 'GCF_001422695.1', 'Leaf82': 'GCF_001422725.1', 
                   'Leaf78': 'GCF_001422735.1', 'Leaf245': 'GCF_942548115.1', 'Leaf87': 'GCF_001422775.1', 'Leaf88': 'GCF_001422795.1', 'Leaf91': 'GCF_001422815.1', 'Leaf100': 'GCF_001422845.1', 'Leaf272': 'GCF_001422865.1', 
                   'Leaf104': 'GCF_001422885.1', 'Leaf106': 'GCF_001422895.1', 'Leaf288': 'GCF_001422925.1', 'Leaf285': 'GCF_001422955.1', 'Leaf117': 'GCF_001422985.1', 'Leaf294': 'GCF_001423005.1', 'Leaf296': 'GCF_001423045.1', 
                   'Leaf299': 'GCF_001423055.1', 'Leaf125': 'GCF_001423085.1', 'Leaf304': 'GCF_001423105.1', 'Leaf126': 'GCF_001423125.1', 'Leaf307': 'GCF_001423135.1', 'Leaf127': 'GCF_001423155.1', 'Leaf314': 'GCF_001423185.1', 
                   'Leaf130': 'GCF_001423205.1', 'Leaf321': 'GCF_001423215.1', 'Leaf324': 'GCF_001423245.1', 'Leaf108': 'GCF_001423265.1', 'Leaf111': 'GCF_001423285.1', 'Leaf112': 'GCF_001423295.1', 'Leaf113': 'GCF_001423325.1', 
                   'Leaf289': 'GCF_001423335.1', 'Leaf291': 'GCF_001423365.1', 'Leaf306': 'GCF_001423425.1', 'Leaf311': 'GCF_001423445.1', 'Leaf129': 'GCF_001423465.1', 'Leaf320': 'GCF_001423485.1', 'Leaf131': 'GCF_001423495.1', 
                   'Leaf325': 'GCF_001423545.1', 'Leaf148': 'GCF_001423585.1', 'Leaf335': 'GCF_001423605.1', 'Leaf159': 'GCF_001423615.1', 'Leaf161': 'GCF_001423645.1', 'Leaf164': 'GCF_001423665.1', 'Leaf168': 'GCF_001423685.1', 
                   'Leaf336': 'GCF_001423695.1', 'Leaf171': 'GCF_001423725.1', 'Leaf337': 'GCF_001423745.1', 'Leaf343': 'GCF_001423765.1', 'Leaf179': 'GCF_001423785.1', 'Leaf347': 'GCF_001423805.1', 'Leaf351': 'GCF_001423825.1', 
                   'Leaf357': 'GCF_001423845.1', 'Leaf182': 'GCF_001423865.2', 'Leaf185': 'GCF_001423885.1', 'Leaf186': 'GCF_001423905.1', 'Leaf187': 'GCF_001423925.1', 'Leaf194': 'GCF_001423945.1', 'Leaf196': 'GCF_001423965.1', 
                   'Leaf359': 'GCF_001423985.1', 'Leaf198': 'GCF_001424005.1', 'Leaf363': 'GCF_001424025.1', 'Leaf371': 'GCF_001424045.1', 'Leaf384': 'GCF_001424065.1', 'Leaf386': 'GCF_001424085.1', 'Leaf394': 'GCF_001424105.1', 
                   'Leaf395': 'GCF_001424125.1', 'Leaf404': 'GCF_001424145.1', 'Leaf139': 'GCF_001424165.1', 'Leaf326': 'GCF_001424185.1', 'Leaf334': 'GCF_001424195.1', 'Leaf151': 'GCF_001424225.1', 'Leaf160': 'GCF_001424265.1', 
                   'Leaf172': 'GCF_001424285.1', 'Leaf176': 'GCF_001424305.1', 'Leaf341': 'GCF_001424325.1', 'Leaf177': 'GCF_001424345.1', 'Leaf354': 'GCF_001424365.1', 'Leaf183': 'GCF_001424385.1', 'Leaf189': 'GCF_001424405.1', 
                   'Leaf191': 'GCF_001424425.1', 'Leaf361': 'GCF_001424445.1', 'Leaf369': 'GCF_001424455.1', 'Leaf380': 'GCF_001424485.1', 'Leaf391': 'GCF_001424505.1', 'Leaf399': 'GCF_001424525.1', 'Leaf400': 'GCF_001424545.1', 
                   'Leaf141': 'GCF_001424565.1', 'Leaf180': 'GCF_001424585.1', 'Leaf154': 'GCF_001424595.1', 'Leaf396': 'GCF_001424605.1', 'Leaf415': 'GCF_001424645.1', 'Leaf416': 'GCF_001424665.1', 'Leaf454': 'GCF_001424685.1', 
                   'Leaf465': 'GCF_001424705.1', 'Leaf436': 'GCF_001424715.1', 'Leaf469': 'GCF_001424745.1', 'Leaf446': 'GCF_001424755.1', 'Leaf383': 'GCF_001425345.1', 'Leaf405': 'GCF_001425355.1', 'Leaf407': 'GCF_001425385.1', 
                   'Leaf412': 'GCF_001425405.1', 'Leaf414': 'GCF_001425425.1', 'Leaf420': 'GCF_001425445.1', 'Leaf427': 'GCF_001425485.1', 'Leaf459': 'GCF_001425495.1', 'Leaf460': 'GCF_001425525.1', 'Leaf434': 'GCF_001425545.1', 
                   'Leaf466': 'GCF_001425565.1', 'Leaf443': 'GCF_001425575.1', 'Leaf453': 'GCF_001425605.1', 'Leaf3': 'GCF_001425965.1', 'Leaf7': 'GCF_001425985.1', 'Leaf94': 'GCF_001426045.1', 'Leaf258': 'GCF_001426065.1', 
                   'Leaf278': 'GCF_001426085.1', 'Leaf49': 'GCF_001426125.1', 'Leaf225': 'GCF_001426145.1', 'Leaf233': 'GCF_001426165.1', 'Leaf247': 'GCF_001426185.1', 'Leaf339': 'GCF_001426195.1', 'Leaf344': 'GCF_001426225.1', 
                   'Leaf98': 'GCF_003258395.1', 'Leaf73': 'GCF_916855635.1', 'Leaf408': 'GCF_916856905.1', 'Leaf350': 'GCF_916858655.1', 'Leaf21': 'GCF_916858675.1', 'Leaf374': 'GCF_916862475.1', 'Leaf37': 'GCF_920939475.1', 
                   'Leaf401': 'GCF_920939485.1', 'Leaf248': 'GCF_920939495.1', 'Leaf4': 'GCF_920939515.1', 'Leaf170': 'GCF_920984665.1', 'Leaf118': 'GCF_920984675.1', 'Leaf59': 'GCF_920984685.1', 'Leaf132': 'GCF_920984695.1', 
                   'Leaf313': 'GCF_920984705.1', 'Leaf205': 'GCF_920984725.1', 'Leaf250': 'GCF_920984735.1'}


def mapping(leafID):
    if leafID not in leaf_to_genbank:
        return 0
    return leaf_to_genbank[leafID]

from pandas import read_table

interaction_table = read_table("Arabatopsis_leaf_negative_interactions.txt")
interaction_table["Inhibitor"] = interaction_table["Inhibitor"].apply(mapping)
interaction_table = interaction_table[interaction_table["Inhibitor"] != 0]
interaction_table["Sensitive"] = interaction_table["Sensitive"].apply(mapping)
interaction_table = interaction_table[interaction_table["Sensitive"] != 0]
display(interaction_table)

# assemble the list of inhibitor-sensitive pairs
from pprint import pprint
pairs = {}
for inhibitor in interaction_table["Inhibitor"].unique():
    pairs[inhibitor] = interaction_table[interaction_table["Inhibitor"] == inhibitor]["Sensitive"].tolist()

negative_pairs = [set([model1+".RAST.fbamodel", model2+".RAST.fbamodel"]) for model1, model2 in zip(interaction_table["Inhibitor"].tolist(), interaction_table["Sensitive"].tolist())]
print(negative_pairs[:10])
# pprint(pairs)   
# pprint([(inhibitor, len(others)) for inhibitor, others in pairs.items()])
# pprint(pairs)
# print(dir(interaction_table.groupby("Inhibitor")))
# Out:
#            Inhibitor        Sensitive Interaction
# 0    GCF_001421285.1  GCF_001423005.1        weak
# 1    GCF_001421285.1  GCF_001424185.1      strong
# 2    GCF_001421285.1  GCF_001424325.1        weak
# 3    GCF_001421285.1  GCF_001426225.1        weak
# 4    GCF_001421285.1  GCF_001423805.1        weak
# ..               ...              ...         ...
# 718  GCF_003258395.1  GCF_001422775.1        weak
# 719  GCF_003258395.1  GCF_001422215.1        weak
# 721  GCF_003258395.1  GCF_001422815.1        weak
# 723  GCF_003258395.1  GCF_001422345.1        weak
# 724  GCF_003258395.1  GCF_001422375.1        weak
#
# [652 rows x 3 columns]
# ...

# %%
all_pairs = [set([model1, model2]) for model1, model2 in zip(combined_df["model1"].tolist(), combined_df["model2"].tolist())]
# print(type(list(combined_df.index)[0]))
non_negative_interactions_df = combined_df.iloc[[index for index, pair in enumerate(all_pairs) if pair not in negative_pairs]]
negative_interactions_df = combined_df.iloc[[index for index, pair in enumerate(all_pairs) if pair in negative_pairs]]

display(non_negative_interactions_df, negative_interactions_df)
# Out:
#                               model1                         model2  \
# 0      GCF_001422165.1.RAST.fbamodel  GCF_001423965.1.RAST.fbamodel
# 1      GCF_001422165.1.RAST.fbamodel  GCF_001424505.1.RAST.fbamodel
# 2      GCF_001422165.1.RAST.fbamodel  GCF_001421245.1.RAST.fbamodel
# 3      GCF_001422165.1.RAST.fbamodel  GCF_001424455.1.RAST.fbamodel
# 4      GCF_001422165.1.RAST.fbamodel  GCF_001422325.1.RAST.fbamodel
# ...                              ...                            ...
# 16466  GCF_920984695.1.RAST.fbamodel  GCF_001422775.1.RAST.fbamodel
# 16467  GCF_920984695.1.RAST.fbamodel  GCF_001421995.1.RAST.fbamodel
# 16468  GCF_001422455.1.RAST.fbamodel  GCF_001422775.1.RAST.fbamodel
# 16469  GCF_001422455.1.RAST.fbamodel  GCF_001421995.1.RAST.fbamodel
# 16470  GCF_001422775.1.RAST.fbamodel  GCF_001421995.1.RAST.fbamodel
#
#             mro_model1       mro_model2  mip       GRD
# 0      0.65000 (26/40)  0.74286 (26/35)   13  1.665175
# ...

# %%
non_negative_interactions_df.iloc[12584]
# Out:
# model1        GCF_001421435.1.RAST.fbamodel
# model2        GCF_001421435.1.RAST.fbamodel
# mro_model1                  1.00000 (33/33)
# mro_model2                              NaN
# mip                                       0
# GRD                                     0.0
# Name: 13087, dtype: object

# %%
non_neg_mip_series = non_negative_interactions_df["mip"]
print(max(non_neg_mip_series))
print(non_neg_mip_series[non_neg_mip_series == max(non_neg_mip_series)].index)
max_cross_feeding_pair = non_negative_interactions_df.loc[non_neg_mip_series[non_neg_mip_series == max(non_neg_mip_series)].index]
# Out:
# 29
# Int64Index([7308], dtype='int64')

# %%
# cFBA analysis for this maximally interacting community

GCF_001421425 = kbase_api.get_from_ws("136582/517/1")
GCF_001421355 = kbase_api.get_from_ws("136582/407/1")
r2a_media = kbase_api.get_from_ws("136582/402/1")

# %run ../../../modelseedpy/community/mscommunity.py
cfba = MSCommunity(models=[GCF_001421425, GCF_001421355])
sol = cfba.run_fba(r2a_media)
cross_feeding, exMets = cfba.interactions(solution=sol, flux_threshold=.1, filename="GCF_001421425+GCF_001421355_syntrophy.csv")
display(cross_feeding)
display(exMets)
# Out:
# cpd11416_c1
# cpd11416_c2
# cpd11416_c0
# bio1: 0.5 cpd11416_c1 + 0.5 cpd11416_c2 --> cpd11416_c0
# primary biomass defined bio1: 0.5 cpd11416_c1 + 0.5 cpd11416_c2 --> cpd11416_c0
# SK_cpd11416_c0: cpd11416_c0 <=>
# cpd11416_c1
# <__main__.MSCommunity object at 0x000002C020927B50> cpd11416_c1
# cpd11416_c2
# <__main__.MSCommunity object at 0x000002C020927B50> cpd11416_c2
# <class 'optlang.glpk_interface.Model'> model loaded
# ic| mssteadycom.py:156 in interactions()
#     normalized_flux: 23.91949649286042
# ic| mssteadycom.py:156 in interactions()
#     normalized_flux: 93.7682691328171
# ic| mssteadycom.py:156 in interactions()
#     normalized_flux: 740.5300052223406
# ic| mssteadycom.py:156 in interactions()
#     normalized_flux: 87.27291783569277
# ic| mssteadycom.py:156 in interactions()
#     normalized_flux: 491.8565690020251
# ic| mssteadycom.py:156 in interactions()
#     normalized_flux: 24.44240370539661
# ic| mssteadycom.py:156 in interactions()
# ...

# %%
# %run ../../../modelseedpy/core/report.py

steadycom_report(cross_feeding, exMets)
# Out:
# '<!DOCTYPE html>\n<html lang="en">\n    <head>\n        <meta http-equiv="Content-type" content="text/html; charset=utf-8">\n        <meta name="viewport" content="width=device-width,initial-scale=1,user-scalable=no">\n        <title>SteadyCom Results</title>\n        <link rel="stylesheet" href="https://stackpath.bootstrapcdn.com/bootstrap/4.4.1/css/bootstrap.min.css" integrity="sha384-Vkoo8x4CGsO3+Hhxv8T/Q5PaXtkKtu6ug5TOeNV6gBiFeWPGFN9MuhOf23Q9Ifjh" crossorigin="anonymous">\n        <link rel="stylesheet" type="text/css" href="https://cdn.datatables.net/1.10.20/css/dataTables.bootstrap4.min.css">\n        <script type="text/javascript" language="javascript" src="https://code.jquery.com/jquery-3.3.1.js"></script>\n        <script src="https://cdn.jsdelivr.net/npm/popper.js@1.16.0/dist/umd/popper.min.js" integrity="sha384-Q6E9RHvbIyZFJoft+2mJbHaEWldlvI9IOYy5n3zV9zzTtmI3UksdQRVvoxMfooAo" crossorigin="anonymous"></script>\n        <script src="https://stackpath.bootstrapcdn.com/bootstr
# ...

# %%
from pandas import read_csv
from matplotlib import pyplot
from numpy import mean, abs, where, delete
from scipy import stats
import sigfig
import re

# mro statistics
## The selection of the maximal MRO value assumes that the interaction type is dependent upon least synergistic interaction in the pairing.
## This perspective is an order-of-magnitude less significant than the average MRO and two orders-of-magnitude less significant than the maximum MRO for each pairing because of outliers.
non_negative_mro_model1 = list(map(float, [re.search(r"(0.\d+)", x).group() for x in non_negative_interactions_df["mro_model1"]]))
    # if not isinstance(x, str):
    #     print(index, x)
        # break
non_negative_mro_model2 = list(map(float, [re.search(r"(0.\d+)", x).group() for x in non_negative_interactions_df["mro_model2"] if isinstance(x, str)]))
non_negative_mro_max = [max(individual_mros) for individual_mros in zip(non_negative_mro_model1, non_negative_mro_model2)]

negative_mro_model1 = list(map(float, [re.search(r"(0.\d+)", x).group() for x in negative_interactions_df["mro_model1"]]))
negative_mro_model2 = list(map(float, [re.search(r"(0.\d+)", x).group() for x in negative_interactions_df["mro_model2"]]))
negative_mro_max = [max(individual_mros) for individual_mros in zip(negative_mro_model1, negative_mro_model2)]

zscore = abs(stats.zscore(negative_mro_max))
negative_mro_max = delete(negative_mro_max, where(zscore > 3))
zscore = abs(stats.zscore(non_negative_mro_max))
non_negative_mro_max = delete(non_negative_mro_max, where(zscore > 3))
ttest = stats.ttest_ind(non_negative_mro_max, negative_mro_max)
print(mean(negative_mro_max), mean(non_negative_mro_max))
print(ttest.pvalue)

pyplot.rc('axes', titlesize=20, labelsize=20)
pyplot.rc('xtick', labelsize=20)
pyplot.rc('ytick', labelsize=20)
pyplot.rc('legend', fontsize=18)
fig = pyplot.figure(figsize=(7,10))

pyplot.boxplot([negative_mro_max, non_negative_mro_max], labels=["'--'", "'o/+'"])
pyplot.scatter([1]*len(negative_mro_max), negative_mro_max)
pyplot.scatter([2]*len(non_negative_mro_max), non_negative_mro_max)
pyplot.xlabel("Interaction type")
pyplot.ylabel("MRO score (overlap)")
pyplot.text(1.2,.7, f"p-value: {sigfig.round(ttest.pvalue, sigfigs=3)}", fontsize="x-large")
fig.savefig("all_v_all MRO comparion.jpg", bbox_inches='tight')


# mip statistics
non_negative_mip = list(map(float, non_negative_interactions_df["mip"]))
negative_mip = list(map(float, negative_interactions_df["mip"]))

ttest = stats.ttest_ind(non_negative_mip, negative_mip)
print(ttest.pvalue)

pyplot.rc('axes', titlesize=20, labelsize=20)
pyplot.rc('xtick', labelsize=20)
pyplot.rc('ytick', labelsize=20)
pyplot.rc('legend', fontsize=18)
fig = pyplot.figure(figsize=(7,10))

pyplot.boxplot([negative_mip, non_negative_mip], labels=["'--'", "'o/+'"])
pyplot.scatter([1]*len(negative_mip), negative_mip)
pyplot.scatter([2]*len(non_negative_mip), non_negative_mip)
pyplot.xlabel("Interaction type")
pyplot.ylabel("MIP score (syntrophy)")
pyplot.text(1.2, 6, f"p-value: {sigfig.round(ttest.pvalue, sigfigs=3)}", fontsize="x-large")
fig.savefig("all_v_all MIP comparion.jpg", bbox_inches='tight')

# biomass yield statistics
non_negative_mro_diff = non_negative_interactions_df["GRD"].to_numpy()
negative_biomass_diff = negative_interactions_df["GRD"].to_numpy()

zscore = abs(stats.zscore(negative_biomass_diff))
# print(list(map(len, [negative_biomass_diff, zscore])))
negative_biomass_diff = delete(negative_biomass_diff, where(zscore > 3))
zscore = abs(stats.zscore(non_negative_mro_diff))
non_negative_mro_diff = delete(non_negative_mro_diff, where(zscore > 3))
ttest = stats.ttest_ind(non_negative_mro_diff, negative_biomass_diff)
print(ttest.pvalue)

pyplot.rc('axes', titlesize=20, labelsize=20)
pyplot.rc('xtick', labelsize=20)
pyplot.rc('ytick', labelsize=20)
pyplot.rc('legend', fontsize=18)
fig = pyplot.figure(figsize=(7,10))

pyplot.boxplot([negative_biomass_diff, non_negative_mro_diff], labels=["'--'", "'o/+'"])
pyplot.scatter([1]*len(negative_biomass_diff), negative_biomass_diff)
pyplot.scatter([2]*len(non_negative_mro_diff), non_negative_mro_diff)
pyplot.xlabel("Interaction type")
pyplot.ylabel("Normalized difference in biomass yield (fitness)")
pyplot.text(1.2, 0.2, f"p-value: {sigfig.round(ttest.pvalue, sigfigs=3)}", fontsize="x-large")
fig.savefig("all_v_all biomass yield comparion.jpg", bbox_inches='tight')

# %%
from pandas import read_csv
from matplotlib import pyplot
from numpy import mean, abs, where, delete
from scipy import stats
import sigfig
import re

non_negative_interactions_df = combined_df.iloc[:1000]
negative_interactions_df = combined_df.iloc[1000:]

# mro statistics
## The selection of the maximal MRO value assumes that the interaction type is dependent upon least synergistic interaction in the pairing.
## This perspective is an order-of-magnitude less significant than the average MRO and two orders-of-magnitude less significant than the maximum MRO for each pairing because of outliers.
non_negative_mro_model1 = list(map(float, [re.search(r"(0.\d+)", x).group() for x in non_negative_interactions_df["mro_model1"]]))
non_negative_mro_model2 = list(map(float, [re.search(r"(0.\d+)", x).group() for x in non_negative_interactions_df["mro_model2"]]))
non_negative_mro_max = [max(individual_mros) for individual_mros in zip(non_negative_mro_model1, non_negative_mro_model2)]

negative_mro_model1 = list(map(float, [re.search(r"(0.\d+)", x).group() for x in negative_interactions_df["mro_model1"]]))
negative_mro_model2 = list(map(float, [re.search(r"(0.\d+)", x).group() for x in negative_interactions_df["mro_model2"]]))
negative_mro_max = [max(individual_mros) for individual_mros in zip(negative_mro_model1, negative_mro_model2)]

zscore = abs(stats.zscore(negative_mro_max))
negative_mro_max = delete(negative_mro_max, where(zscore > 3))
zscore = abs(stats.zscore(non_negative_mro_max))
non_negative_mro_max = delete(non_negative_mro_max, where(zscore > 3))
ttest = stats.ttest_ind(non_negative_mro_max, negative_mro_max)
print(mean(negative_mro_max), mean(non_negative_mro_max))
print(ttest.pvalue)

pyplot.rc('axes', titlesize=20, labelsize=20)
pyplot.rc('xtick', labelsize=20)
pyplot.rc('ytick', labelsize=20)
pyplot.rc('legend', fontsize=18)
fig = pyplot.figure(figsize=(7,10))

pyplot.boxplot([negative_mro_max, non_negative_mro_max], labels=["'--'", "'o/+'"])
pyplot.scatter([1]*len(negative_mro_max), negative_mro_max)
pyplot.scatter([2]*len(non_negative_mro_max), non_negative_mro_max)
pyplot.xlabel("Interaction type")
pyplot.ylabel("MRO score (overlap)")
pyplot.text(1.2,.7, f"p-value: {sigfig.round(ttest.pvalue, sigfigs=3)}", fontsize="x-large")
fig.savefig("all_v_all MRO comparion.jpg", bbox_inches='tight')


# mip statistics
non_negative_mip = list(map(float, non_negative_interactions_df["mip"]))
negative_mip = list(map(float, negative_interactions_df["mip"]))

ttest = stats.ttest_ind(non_negative_mip, negative_mip)
print(ttest.pvalue)

pyplot.rc('axes', titlesize=20, labelsize=20)
pyplot.rc('xtick', labelsize=20)
pyplot.rc('ytick', labelsize=20)
pyplot.rc('legend', fontsize=18)
fig = pyplot.figure(figsize=(7,10))

pyplot.boxplot([negative_mip, non_negative_mip], labels=["'--'", "'o/+'"])
pyplot.scatter([1]*len(negative_mip), negative_mip)
pyplot.scatter([2]*len(non_negative_mip), non_negative_mip)
pyplot.xlabel("Interaction type")
pyplot.ylabel("MIP score (syntrophy)")
pyplot.text(1.2, 6, f"p-value: {sigfig.round(ttest.pvalue, sigfigs=3)}", fontsize="x-large")
fig.savefig("all_v_all MIP comparion.jpg", bbox_inches='tight')

# biomass yield statistics
non_negative_mro_diff = non_negative_interactions_df["GRD"].to_numpy()
negative_biomass_diff = negative_interactions_df["GRD"].to_numpy()

zscore = abs(stats.zscore(negative_biomass_diff))
# print(list(map(len, [negative_biomass_diff, zscore])))
negative_biomass_diff = delete(negative_biomass_diff, where(zscore > 3))
zscore = abs(stats.zscore(non_negative_mro_diff))
non_negative_mro_diff = delete(non_negative_mro_diff, where(zscore > 3))
ttest = stats.ttest_ind(non_negative_mro_diff, negative_biomass_diff)
print(ttest.pvalue)

pyplot.rc('axes', titlesize=20, labelsize=20)
pyplot.rc('xtick', labelsize=20)
pyplot.rc('ytick', labelsize=20)
pyplot.rc('legend', fontsize=18)
fig = pyplot.figure(figsize=(7,10))

pyplot.boxplot([negative_biomass_diff, non_negative_mro_diff], labels=["'--'", "'o/+'"])
pyplot.scatter([1]*len(negative_biomass_diff), negative_biomass_diff)
pyplot.scatter([2]*len(non_negative_mro_diff), non_negative_mro_diff)
pyplot.xlabel("Interaction type")
pyplot.ylabel("Normalized difference in biomass yield (fitness)")
pyplot.text(1.2, 0.2, f"p-value: {sigfig.round(ttest.pvalue, sigfigs=3)}", fontsize="x-large")
fig.savefig("all_v_all biomass yield comparion.jpg", bbox_inches='tight')
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[3], line 19
#      16 non_negative_mro_max = [max(individual_mros) for individual_mros in zip(non_negative_mro_model1, non_negative_mro_model2)]
#      18 negative_mro_model1 = list(map(float, [re.search(r"(0.\d+)", x).group() for x in negative_interactions_df["mro_model1"]]))
# ---> 19 negative_mro_model2 = list(map(float, [re.search(r"(0.\d+)", x).group() for x in negative_interactions_df["mro_model2"]]))
#      20 negative_mro_max = [max(individual_mros) for individual_mros in zip(negative_mro_model1, negative_mro_model2)]
#      22 zscore = abs(stats.zscore(negative_mro_max))
#
# Cell In[3], line 19, in <listcomp>(.0)
#      16 non_negative_mro_max = [max(individual_mros) for individual_mros in zip(non_negative_mro_model1, non_negative_mro_model2)]
# ...

# %% [markdown]
# # Reprocess the 10x10 PMI dataset

# %%
from pandas import read_csv
from matplotlib import pyplot
from numpy import mean, abs, where, delete
from scipy import stats
import sigfig
import re

combined_PMI_df = read_csv("combined_PMI_report.csv").drop(["Unnamed: 0"], axis=1)
negative_PMI_df = combined_PMI_df.iloc[:7]
non_negative_PMI_df = combined_PMI_df.iloc[7:]

# mro statistics
## The selection of the maximal MRO value assumes that the interaction type is dependent upon least synergistic interaction in the pairing.
## This perspective is an order-of-magnitude less significant than the average MRO and two orders-of-magnitude less significant than the maximum MRO for each pairing because of outliers.
non_negative_mro_model1 = list(map(float, [re.search(r"(0.\d+)", x).group() for x in non_negative_PMI_df["mro_model1"]]))
non_negative_mro_model2 = list(map(float, [re.search(r"(0.\d+)", x).group() for x in non_negative_PMI_df["mro_model2"]]))
non_negative_mro_max = [max(individual_mros) for individual_mros in zip(non_negative_mro_model1, non_negative_mro_model2)]

negative_mro_model1 = list(map(float, [re.search(r"(0.\d+)", x).group() for x in negative_PMI_df["mro_model1"]]))
negative_mro_model2 = list(map(float, [re.search(r"(0.\d+)", x).group() for x in negative_PMI_df["mro_model2"]]))
negative_mro_max = [max(individual_mros) for individual_mros in zip(negative_mro_model1, negative_mro_model2)]

zscore = abs(stats.zscore(negative_mro_max))
negative_mro_max = delete(negative_mro_max, where(zscore > 2))
zscore = abs(stats.zscore(non_negative_mro_max))
non_negative_mro_max = delete(non_negative_mro_max, where(zscore > 2))
ttest = stats.ttest_ind(non_negative_mro_max, negative_mro_max)
print(mean(negative_mro_max), mean(non_negative_mro_max))
print(ttest.pvalue)

pyplot.rc('axes', titlesize=20, labelsize=20)
pyplot.rc('xtick', labelsize=20)
pyplot.rc('ytick', labelsize=20)
pyplot.rc('legend', fontsize=18)
fig = pyplot.figure(figsize=(7,10))

pyplot.boxplot([negative_mro_max, non_negative_mro_max], labels=["'--'", "'o/+'"])
pyplot.scatter([1]*len(negative_mro_max), negative_mro_max)
pyplot.scatter([2]*len(non_negative_mro_max), non_negative_mro_max)
pyplot.xlabel("Interaction type")
pyplot.ylabel("MRO score (overlap)")
pyplot.text(1.2,.7, f"p-value: {sigfig.round(ttest.pvalue, sigfigs=3)}", fontsize="x-large")
fig.savefig("PMI MRO comparion.jpg", bbox_inches='tight')


# mip statistics
non_negative_mip = list(map(float, non_negative_PMI_df["mip"]))
negative_mip = list(map(float, negative_PMI_df["mip"]))

ttest = stats.ttest_ind(non_negative_mip, negative_mip)
print(ttest.pvalue)

pyplot.rc('axes', titlesize=20, labelsize=20)
pyplot.rc('xtick', labelsize=20)
pyplot.rc('ytick', labelsize=20)
pyplot.rc('legend', fontsize=18)
fig = pyplot.figure(figsize=(7,10))

pyplot.boxplot([negative_mip, non_negative_mip], labels=["'--'", "'o/+'"])
pyplot.scatter([1]*len(negative_mip), negative_mip)
pyplot.scatter([2]*len(non_negative_mip), non_negative_mip)
pyplot.xlabel("Interaction type")
pyplot.ylabel("MIP score (syntrophy)")
pyplot.text(1.2, 6, f"p-value: {sigfig.round(ttest.pvalue, sigfigs=3)}", fontsize="x-large")
fig.savefig("PMI MIP comparion.jpg", bbox_inches='tight')

# biomass yield statistics
non_negative_mro_diff = non_negative_PMI_df["growth_diff"].to_numpy()
negative_biomass_diff = negative_PMI_df["growth_diff"].to_numpy()

zscore = abs(stats.zscore(negative_biomass_diff))
# print(list(map(len, [negative_biomass_diff, zscore])))
negative_biomass_diff = delete(negative_biomass_diff, where(zscore > 2))
zscore = abs(stats.zscore(non_negative_mro_diff))
non_negative_mro_diff = delete(non_negative_mro_diff, where(zscore > 2))
ttest = stats.ttest_ind(non_negative_mro_diff, negative_biomass_diff)
print(ttest.pvalue)

pyplot.rc('axes', titlesize=20, labelsize=20)
pyplot.rc('xtick', labelsize=20)
pyplot.rc('ytick', labelsize=20)
pyplot.rc('legend', fontsize=18)
fig = pyplot.figure(figsize=(7,10))

pyplot.boxplot([negative_biomass_diff, non_negative_mro_diff], labels=["'--'", "'o/+'"])
pyplot.scatter([1]*len(negative_biomass_diff), negative_biomass_diff)
pyplot.scatter([2]*len(non_negative_mro_diff), non_negative_mro_diff)
pyplot.xlabel("Interaction type")
pyplot.ylabel("Normalized difference in biomass yield (fitness)")
pyplot.text(1.2, 0.2, f"p-value: {sigfig.round(ttest.pvalue, sigfigs=3)}", fontsize="x-large")
fig.savefig("PMI biomass yield comparion.jpg", bbox_inches='tight')
# Out:
# 0.8647566666666666 0.7935023076923076
# 0.039640753188393676
# 0.7607591575202659
# 0.031176102553296982

# %%
combined_df[combined_df.index.duplicated()]
# Out:
# Empty DataFrame
# Columns: [Unnamed: 0, model1, model2, mro_model1, mro_model2, mip, model1_biomass yield, model2_biomass yield]
# Index: []

# %%
combined_PMI_df
# Out:
#                                         model1  \
# 0              Bacillus_sp._bc15.RAST.fbamodel
# 1     Sphingobium_AP49_pacbio_v2.RAST.fbamodel
# 2     Variovorax_CF313_pacbio_v2.RAST.fbamodel
# 3     Caulobacter_AP07_pacbio_v2.RAST.fbamodel
# 4     Pseudomonas_GM17_pacbio_v2.RAST.fbamodel
# 5          Burkholderia_sp._BT03.RAST.fbamodel
# 6     Variovorax_CF313_pacbio_v2.RAST.fbamodel
# 7     Caulobacter_AP07_pacbio_v2.RAST.fbamodel
# 8     Pseudomonas_GM17_pacbio_v2.RAST.fbamodel
# 9              Bacillus_sp._bc15.RAST.fbamodel
# 10    Variovorax_CF313_pacbio_v2.RAST.fbamodel
# 11  Streptomyces_YR139_pacbio_v2.RAST.fbamodel
# 12             Bacillus_sp._bc15.RAST.fbamodel
# 13    Sphingobium_AP49_pacbio_v2.RAST.fbamodel
# 14    Sphingobium_AP49_pacbio_v2.RAST.fbamodel
# 15    Sphingobium_AP49_pacbio_v2.RAST.fbamodel
# 16    Caulobacter_AP07_pacbio_v2.RAST.fbamodel
# 17    Caulobacter_AP07_pacbio_v2.RAST.fbamodel
# 18    Variovorax_CF313_pacbio_v2.RAST.fbamodel
# ...
