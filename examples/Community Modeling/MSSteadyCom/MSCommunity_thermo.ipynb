# %%
class test:
    def __init__(self,):
        self.name = 'this'
        
    def test(self,):
        if hasattr(self,'name'):
            print('yes')
        if not hasattr(self,'bread'):
            print('no')
            
tst = test()
print(tst.test())

# %%
def exchange_list(): 
    return [rxn for rxn in model.reactions if 'EX_' in rxn.id]

for rx in exchange_list():
    print(rx.id)
    break

# from pprint import pprint
# for rxn in model.exchanges:
#     pprint(rxn.id)

# %%
sol = model.optimize()
print(type(sol))

# %%
print(type(media))

# %%
x = 2
b = None
print(all(i is None for i in [x,b]))

# %%
for met in model.metabolites:
    if met in None:
        print('yes')
    print(dir(met))
    print(met.elements)
    break

# %% [markdown]
# # Import KBase and mscom

# %%
# import kbase
import os
local_cobrakbase_path = os.path.join('C:', 'Users', 'Andrew Freiburger','Documents','Argonne','cobrakbase')
os.environ["HOME"] = local_cobrakbase_path

import cobrakbase
with open("C:/Users/Andrew Freiburger/Documents/Argonne/kbase_token.txt") as token_file:
    kbase = cobrakbase.KBaseAPI(token_file.readline())

model = kbase.get_from_ws("CMM_iAH991V2_iML1515.kb",40576)
media = kbase.get_from_ws("Btheta_Ecoli_minimal_media",40576)

# %matplotlib inline
# Out:
# cobrakbase 0.3.1

# %% [markdown]
# # 2-member Zahmeeth model

# %% [markdown]
# ## Unconstained model

# %% [markdown]
# ### Define and execute the model

# %%
model = kbase.get_from_ws("CMM_iAH991V2_iML1515.kb",40576)
media = kbase.get_from_ws("Btheta_Ecoli_minimal_media",40576)

# simulate and visualize the model
from modelseedpy import MSCommunity
# %run ../../../modelseedpy/community/mssteadycom.py
cross_feeding_df, exMets_df = MSSteadyCom(MSCommunity(model), media)
display(cross_feeding_df)
display(exMets_df)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 model = kbase.get_from_ws("CMM_iAH991V2_iML1515.kb",40576)
#       2 media = kbase.get_from_ws("Btheta_Ecoli_minimal_media",40576)
#       4 # simulate and visualize the model
#
# NameError: name 'kbase' is not defined

# %% [markdown]
# # SimpleThermo-constrained

# %%
# %%time

# from modelseedpy import MSCommunity
# %run ../../../modelseedpy/community/mscommunity.py
# %run ../../../modelseedpy/community/mssteadycom.py

mscomm = MSCommunity(model)
mscomm.constrain(thermo_params={"dgbin":False})
cross_feeding_df, exMets_df = MSSteadyCom.compute(mscomm)
display(cross_feeding_df)
display(exMets_df)
# Out:
# cpd11416_c0
# bio1: 0.5 cpd11416_c1 + 0.5 cpd11416_c2 --> cpd11416_c0
# primary biomass defined bio1: 0.5 cpd11416_c1 + 0.5 cpd11416_c2 --> cpd11416_c0
# SK_cpd11416_c0: cpd11416_c0 -->
# cpd11416_c1
# cpd11416_c2
# cpd11416_c1
# c1
# cpd11416_c2
# c2
# ...

# %% [markdown]
# ## FullThermo-constrained model

# %% [markdown]
# ### Define and execute the model

# %%
# %%time
# import the model
# from modelseedpy.fbapkg import kbasemediapkg

# modelInfo_2 = ["CMM_iAH991V2_iML1515.kb",40576]
# mediaInfo_2 = ["Btheta_Ecoli_minimal_media",40576]

# model = kbase.get_from_ws(modelInfo_2[0],modelInfo_2[1])
# media = kbase.get_from_ws(mediaInfo_2[0],mediaInfo_2[1])
# kmp = kbasemediapkg.KBaseMediaPkg(self.model)
# kmp.build_package(media)

# simulate and visualize the model
# %run ../../../modelseedpy/community/mscommunity.py
mscom = MSCommunity(model)
mscom.gapfill(media)
mscom.constrain(msdb_path = os.path.join('C:', 'Users', 'Andrew Freiburger','Documents','Argonne','ModelSEED', "ModelSEEDDatabase"))
solution = mscom.run()
mscom.compute_interactions(solution)
mscom.visualize()
# Out:
# cpd11416_c0
# bio1: 0.5 cpd11416_c1 + 0.5 cpd11416_c2 --> cpd11416_c0
# primary biomass defined bio1: 0.5 cpd11416_c1 + 0.5 cpd11416_c2 --> cpd11416_c0
# SK_cpd11416_c0: cpd11416_c0 -->
# cpd11416_c1
# cpd11416_c2
# cpd11416_c1
# c1
# cpd11416_c2
# c2
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# File <timed exec>:16, in <module>
#
# File ~\Documents\Argonne\ModelSEED\ModelSEEDpy\modelseedpy\community\mscommunity.py:301, in MSCommunity.constrain(self, element_uptake_limit, kinetic_coeff, msdb_path)
#     299 self.msdb_path = msdb_path
#     300 if msdb_path:
# --> 301     self.pkgmgr.getpkg("FullThermoPkg").build_package({'modelseed_db_path':msdb_path})
#
# File ~\AppData\Local\Programs\Python\Python39\lib\site-packages\modelseedpy\fbapkg\fullthermopkg.py:72, in FullThermoPkg.build_package(self, parameters, verbose)
#      57 # amalgamate default and specified paramters
# ...

# %% [markdown]
# # 3-member Electrosynth model

# %% [markdown]
# ## Unconstrained model

# %% [markdown]
# ### Define and execute the model

# %%
# import the model
# from modelseedpy.fbapkg import kbasemediapkg

modelInfo_2 = ['electrosynth_comnty.mdl.gf.2021',93204]
mediaInfo_2 = ["CO2_minimal",93204]

model = kbase.get_from_ws(modelInfo_2[0],modelInfo_2[1])
media = kbase.get_from_ws(mediaInfo_2[0],mediaInfo_2[1])
# kmp = kbasemediapkg.KBaseMediaPkg(self.model)
# kmp.build_package(media)

# simulate and visualize the model
mscom = MSCommunity(model)
mscom.drain_fluxes(media)
mscom.gapfill(media)
mscom.constrain(media)
solution = mscom.run()
mscom.compute_interactions(solution)
mscom.visualize()

# %% [markdown]
# ## FullThermo-constrained model

# %% [markdown]
# ### Define and execute the model

# %%
# import the model
# from modelseedpy.fbapkg import kbasemediapkg

modelInfo_2 = ['electrosynth_comnty.mdl.gf.2021',93204]
mediaInfo_2 = ["CO2_minimal",93204]

model = kbase.get_from_ws(modelInfo_2[0],modelInfo_2[1])
media = kbase.get_from_ws(mediaInfo_2[0],mediaInfo_2[1])
# kmp = kbasemediapkg.KBaseMediaPkg(self.model)
# kmp.build_package(media)

# simulate and visualize the model
mscom = MSCommunity(model)
mscom.drain_fluxes(media)
mscom.gapfill(media)
mscom.constrain(media, msdb_path_for_fullthermo = ftp_path, verbose = False)
solution = mscom.run()
mscom.compute_interactions(solution)
mscom.visualize()

# %% [markdown]
# # 2-member Aimee model

# %% [markdown]
# ## Unconstrained model

# %% [markdown]
# ### Chitin media

# %%
# import the model
# %run ../../../modelseedpy/core/mscommunity.py
# from modelseedpy.fbapkg import kbasemediapkg

modelInfo_2 = ['Cjaponicus_Ecoli_Community',97055]
mediaInfo_2 = ["ChitinM9Media",97055]

model = kbase.get_from_ws(modelInfo_2[0],modelInfo_2[1])
media = kbase.get_from_ws(mediaInfo_2[0],mediaInfo_2[1])
# kmp = kbasemediapkg.KBaseMediaPkg(self.model)
# kmp.build_package(media)

# simulate and visualize the model
mscom = MSCommunity(model)
mscom.drain_fluxes(media)
mscom.gapfill(media)
mscom.constrain(media) 
solution = mscom.run()
mscom.compute_interactions(solution)
mscom.visualize()

# %% [markdown]
# ## FullThermo-constrained model

# %% [markdown]
# ### Define and execute the model

# %%
# import the model
# from modelseedpy.fbapkg import kbasemediapkg

modelInfo_2 = ['Cjaponicus_Ecoli_Community',97055]
mediaInfo_2 = ["ChitinM9Media",97055]

model = kbase.get_from_ws(modelInfo_2[0],modelInfo_2[1])
media = kbase.get_from_ws(mediaInfo_2[0],mediaInfo_2[1])
# kmp = kbasemediapkg.KBaseMediaPkg(self.model)
# kmp.build_package(media)

# simulate and visualize the model
mscom = MSCommunity(model)
mscom.drain_fluxes(media)
mscom.gapfill(media)
mscom.constrain(media, msdb_path_for_fullthermo = ftp_path, verbose = False)
solution = mscom.run()
mscom.compute_interactions(solution)
mscom.visualize()

# %% [markdown]
# # 7-member Hotlake model

# %% [markdown]
# ## Unconstrained model

# %% [markdown]
# ### Define and execute the model

# %%
# import the model
# %run ../../../modelseedpy/core/mscommunity.py
# from modelseedpy.fbapkg import kbasemediapkg

modelInfo_2 = ["Hot_Lake_seven.mdl",93544]
mediaInfo_2 = ["HotLakeMedia",93544]

model = kbase.get_from_ws(modelInfo_2[0],modelInfo_2[1])
media = kbase.get_from_ws(mediaInfo_2[0],mediaInfo_2[1])
# kmp = kbasemediapkg.KBaseMediaPkg(self.model)
# kmp.build_package(media)

# simulate and visualize the model
mscom = MSCommunity(model)
mscom.drain_fluxes(media)
mscom.gapfill(media)
mscom.constrain(media)
solution = mscom.run()
mscom.compute_interactions(solution)
mscom.visualize()

# %% [markdown]
# ## FullThermo-constrained model

# %% [markdown]
# ### Define and execute the model

# %%
# import the model
# %run ../../modelseedpy/core/mscommunity.py
# from modelseedpy.fbapkg import kbasemediapkg

modelInfo_2 = ["Hot_Lake_seven.mdl",93544]
mediaInfo_2 = ["HotLakeMedia",93544]

model = kbase.get_from_ws(modelInfo_2[0],modelInfo_2[1])
media = kbase.get_from_ws(mediaInfo_2[0],mediaInfo_2[1])
# kmp = kbasemediapkg.KBaseMediaPkg(self.model)
# kmp.build_package(media)

# simulate and visualize the model
mscom = MSCommunity(model)
mscom.drain_fluxes(media)
mscom.gapfill(media)
mscom.constrain(media, msdb_path_for_fullthermo = ftp_path, verbose = False)
solution = mscom.run()
mscom.compute_interactions(solution)
mscom.visualize()
